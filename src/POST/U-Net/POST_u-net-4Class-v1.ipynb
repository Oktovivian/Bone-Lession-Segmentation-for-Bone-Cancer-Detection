# %%
# CELL 1
import os
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
)
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import accuracy_score, jaccard_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random

# %%
# CELL 2
# Define variables
img_height = 512
img_width = 128
channels = 3
num_classes = 4

batch_size = 4   # Increased batch size for stability
epochs = 20      # Increased epochs for better training

# Paths to the datasets
image_dir = r"/kaggle/input/whole-body-bone-scan-with-mask/POST WBBS 4 Class/Whole Body Bone Scan POST"
mask_dir = r"/kaggle/input/whole-body-bone-scan-with-mask/POST WBBS 4 Class/Mask V4 - Posterior 4 Class"

# Directory to save model checkpoints
checkpoint_dir = r"/kaggle/working/"
os.makedirs(checkpoint_dir, exist_ok=True)

# %%
# CELL 3
images = []
masks = []

# Get list of image files
image_files = [
    f for f in os.listdir(image_dir) if f.endswith('.jpg') or f.endswith('.png')
]

# Load images and corresponding masks
for file in image_files:
    # Load and resize image
    image_path = os.path.join(image_dir, file)
    image = cv2.imread(image_path)
    if image is None:
        print(f"Could not read image {file}, skipping.")
        continue
    # Resize image: cv2.resize expects (width, height)
    image = cv2.resize(image, (img_width, img_height))
    image = image / 255.0  # Normalize image

    # Construct mask filename
    base_filename = os.path.splitext(file)[0]
    mask_filename = base_filename + '_colored_mask.npy'  # Adjust based on your mask filename pattern
    mask_path = os.path.join(mask_dir, mask_filename)
    if not os.path.exists(mask_path):
        print(f"Mask not found for image {file}, skipping.")
        continue

    # Load and resize mask
    mask = np.load(mask_path)
    mask = cv2.resize(mask, (img_width, img_height), interpolation=cv2.INTER_NEAREST)

    # Check unique values in mask
    unique_values = np.unique(mask)
    print(f"Unique values in {mask_filename}: {unique_values}")
    if not np.all(np.isin(unique_values, [0, 1, 2, 3])):
        print(f"Unexpected values in mask for {file}, skipping.")
        continue

    # Convert mask to one-hot encoding
    mask_one_hot = np.zeros((img_height, img_width, num_classes), dtype=np.uint8)
    for i in range(num_classes):
        mask_one_hot[..., i] = (mask == i).astype(np.uint8)

    images.append(image)
    masks.append(mask_one_hot)

# Convert lists to NumPy arrays
images = np.array(images)
masks = np.array(masks)

# Print the shapes
# print("Images shape:", images.shape)  # Expected: (num_samples, img_height, img_width, channels)
# print("Masks shape:", masks.shape)    # Expected: (num_samples, img_height, img_width, num_classes)


# THIS IS CHANGEABLE
# EXPERIMENTAL CODE
# CELL 3

# Initialize lists to hold images and masks
# Out:
# Unique values in 1269_colored_mask.npy: [0 1 2 3]
# Unique values in 623_colored_mask.npy: [0 1 3]
# Unique values in 2008_colored_mask.npy: [0 1 3]
# Unique values in 2081_colored_mask.npy: [0 1 2]
# Unique values in 3138_colored_mask.npy: [0 1 2]
# Unique values in 764_colored_mask.npy: [0 1 3]
# Unique values in 1700_colored_mask.npy: [0 1 3]
# Unique values in 1786_colored_mask.npy: [0 1 3]
# Unique values in 2907_colored_mask.npy: [0 1 3]
# Unique values in 1075_colored_mask.npy: [0 1 3]
# Unique values in 2863_colored_mask.npy: [0 1 2 3]
# Unique values in 771_colored_mask.npy: [0 1 3]
# Unique values in 208_colored_mask.npy: [0 1 3]
# Unique values in 2628_colored_mask.npy: [0 1 3]
# Unique values in 1789_colored_mask.npy: [0 1 3]
# Unique values in 473_colored_mask.npy: [0 1 2 3]
# Unique values in 1792_colored_mask.npy: [0 1 3]
# Unique values in 2936_colored_mask.npy: [0 1 3]
# Unique values in 2029_colored_mask.npy: [0 1 2 3]
# Unique values in 1411_colored_mask.npy: [0 1 2 3]
# Unique values in 1031_colored_mask.npy: [0 1 3]
# Unique values in 2675_colored_mask.npy: [0 1 2 3]
# Unique values in 2172_colored_mask.npy: [0 1 3]
# Unique values in 1749_colored_mask.npy: [0 1 3]
# Unique values in 2021_colored_mask.npy: [0 1 2 3]
# Unique values in 1995_colored_mask.npy: [0 1 2 3]
# Unique values in 1971_colored_mask.npy: [0 1 3]
# Unique values in 1383_colored_mask.npy: [0 1 3]
# Unique values in 333_colored_mask.npy: [0 1 3]
# Unique values in 1354_colored_mask.npy: [0 1 3]
# Unique values in 1024_colored_mask.npy: [0 1 2 3]
# Unique values in 537_colored_mask.npy: [0 1 2 3]
# Unique values in 3014_colored_mask.npy: [0 1 2 3]
# Unique values in 45_colored_mask.npy: [0 1 2 3]
# Unique values in 2375_colored_mask.npy: [0 1 3]
# Unique values in 56_colored_mask.npy: [0 1 3]
# Unique values in 654_colored_mask.npy: [0 1 2]
# Unique values in 89_colored_mask.npy: [0 1 3]
# Unique values in 1711_colored_mask.npy: [0 1 3]
# Unique values in 20_colored_mask.npy: [0 1 2]
# Unique values in 1339_colored_mask.npy: [0 1 3]
# Unique values in 275_colored_mask.npy: [0 1 2 3]
# Unique values in 2532_colored_mask.npy: [0 1 3]
# Unique values in 1161_colored_mask.npy: [0 1 3]
# Unique values in 2262_colored_mask.npy: [0 1 3]
# Unique values in 2213_colored_mask.npy: [0 1 2 3]
# Unique values in 1940_colored_mask.npy: [0 1 3]
# Unique values in 1777_colored_mask.npy: [0 1 3]
# Unique values in 1380_colored_mask.npy: [0 1 3]
# Unique values in 212_colored_mask.npy: [0 1 2 3]
# Unique values in 239_colored_mask.npy: [0 1 3]
# Unique values in 2057_colored_mask.npy: [0 1 3]
# Unique values in 1009_colored_mask.npy: [0 1 2]
# Unique values in 2094_colored_mask.npy: [0 1 3]
# Unique values in 1157_colored_mask.npy: [0 1 3]
# Unique values in 58_colored_mask.npy: [0 1 2 3]
# Unique values in 2302_colored_mask.npy: [0 1 2 3]
# Unique values in 2695_colored_mask.npy: [0 1 3]
# Unique values in 1340_colored_mask.npy: [0 1 2]
# Unique values in 1760_colored_mask.npy: [0 1 3]
# Unique values in 2028_colored_mask.npy: [0 1 3]
# Unique values in 1173_colored_mask.npy: [0 1 3]
# Unique values in 2137_colored_mask.npy: [0 1 3]
# Unique values in 6_colored_mask.npy: [0 1 3]
# Unique values in 109_colored_mask.npy: [0 1 2 3]
# Unique values in 2654_colored_mask.npy: [0 1 3]
# Unique values in 3209_colored_mask.npy: [0 1 3]
# Unique values in 2319_colored_mask.npy: [0 1 2]
# Unique values in 149_colored_mask.npy: [0 1 3]
# Unique values in 1488_colored_mask.npy: [0 1 2 3]
# Unique values in 1644_colored_mask.npy: [0 1 3]
# Unique values in 1539_colored_mask.npy: [0 1 2 3]
# Unique values in 2640_colored_mask.npy: [0 1 3]
# Unique values in 187_colored_mask.npy: [0 1 2 3]
# Unique values in 436_colored_mask.npy: [0 1 2 3]
# Unique values in 76_colored_mask.npy: [0 1 2 3]
# Unique values in 539_colored_mask.npy: [0 1 3]
# Unique values in 2844_colored_mask.npy: [0 1 3]
# Unique values in 1355_colored_mask.npy: [0 1 3]
# Unique values in 355_colored_mask.npy: [0 1]
# Unique values in 2041_colored_mask.npy: [0 1 3]
# Unique values in 516_colored_mask.npy: [0 1 3]
# Unique values in 1409_colored_mask.npy: [0 1 2 3]
# Unique values in 71_colored_mask.npy: [0 1 2 3]
# Unique values in 708_colored_mask.npy: [0 1 2 3]
# Unique values in 1222_colored_mask.npy: [0 1 3]
# Unique values in 1154_colored_mask.npy: [0 1 3]
# Unique values in 474_colored_mask.npy: [0 1 3]
# Unique values in 1840_colored_mask.npy: [0 1 3]
# Unique values in 3207_colored_mask.npy: [0 1 2 3]
# Unique values in 2580_colored_mask.npy: [0 1 3]
# Unique values in 1124_colored_mask.npy: [0 1 3]
# Unique values in 501_colored_mask.npy: [0 1 3]
# Unique values in 1395_colored_mask.npy: [0 1 2 3]
# Unique values in 2363_colored_mask.npy: [0 1 2 3]
# Unique values in 915_colored_mask.npy: [0 1 2 3]
# Unique values in 815_colored_mask.npy: [0 1 2]
# Unique values in 2704_colored_mask.npy: [0 1 3]
# Unique values in 817_colored_mask.npy: [0 1 3]
# Unique values in 2003_colored_mask.npy: [0 1 2 3]
# Unique values in 429_colored_mask.npy: [0 1 3]
# Unique values in 2000_colored_mask.npy: [0 1 2 3]
# Unique values in 1055_colored_mask.npy: [0 1 3]
# Unique values in 2560_colored_mask.npy: [0 1 2 3]
# Unique values in 646_colored_mask.npy: [0 1 2]
# Unique values in 2753_colored_mask.npy: [0 1 3]
# Unique values in 682_colored_mask.npy: [0 1 3]
# Unique values in 1548_colored_mask.npy: [0 1 3]
# Unique values in 3198_colored_mask.npy: [0 1 3]
# Unique values in 1934_colored_mask.npy: [0 1 3]
# Unique values in 544_colored_mask.npy: [0 1 2 3]
# Unique values in 2953_colored_mask.npy: [0 1 2 3]
# Unique values in 2279_colored_mask.npy: [0 1 3]
# Unique values in 377_colored_mask.npy: [0 1 2 3]
# Unique values in 1026_colored_mask.npy: [0 1 2 3]
# Unique values in 2866_colored_mask.npy: [0 1 3]
# Unique values in 272_colored_mask.npy: [0 1 3]
# Unique values in 270_colored_mask.npy: [0 1 2 3]
# Unique values in 182_colored_mask.npy: [0 1 2]
# Unique values in 2182_colored_mask.npy: [0 1 3]
# Unique values in 1936_colored_mask.npy: [0 1 3]
# Unique values in 1162_colored_mask.npy: [0 1 3]
# Unique values in 3195_colored_mask.npy: [0 1 2 3]
# Unique values in 215_colored_mask.npy: [0 1 2 3]
# Unique values in 2558_colored_mask.npy: [0 1 2 3]
# Unique values in 576_colored_mask.npy: [0 1 3]
# Unique values in 2571_colored_mask.npy: [0 1 2 3]
# Unique values in 2749_colored_mask.npy: [0 1 3]
# Unique values in 2526_colored_mask.npy: [0 1 2 3]
# Unique values in 1484_colored_mask.npy: [0 1 3]
# Unique values in 3064_colored_mask.npy: [0 1 3]
# Unique values in 2751_colored_mask.npy: [0 1 3]
# Unique values in 1920_colored_mask.npy: [0 1 3]
# Unique values in 613_colored_mask.npy: [0 1 3]
# Unique values in 930_colored_mask.npy: [0 1 3]
# Unique values in 243_colored_mask.npy: [0 1 3]
# Unique values in 2748_colored_mask.npy: [0 1 3]
# Unique values in 1702_colored_mask.npy: [0 1 2]
# Unique values in 2510_colored_mask.npy: [0 1 3]
# Unique values in 1010_colored_mask.npy: [0 1 2 3]
# Unique values in 153_colored_mask.npy: [0 1 3]
# Unique values in 2743_colored_mask.npy: [0 1 2]
# Unique values in 703_colored_mask.npy: [0 1 2 3]
# Unique values in 2852_colored_mask.npy: [0 1 2]
# Unique values in 1451_colored_mask.npy: [0 1 2 3]
# Unique values in 189_colored_mask.npy: [0 1 3]
# Unique values in 143_colored_mask.npy: [0 1 2]
# Unique values in 2719_colored_mask.npy: [0 1 3]
# Unique values in 2486_colored_mask.npy: [0 1]
# Unique values in 1025_colored_mask.npy: [0 1 2 3]
# Unique values in 2444_colored_mask.npy: [0 1 3]
# Unique values in 3085_colored_mask.npy: [0 1 2 3]
# Unique values in 1343_colored_mask.npy: [0 1 3]
# Unique values in 1579_colored_mask.npy: [0 1 3]
# Unique values in 1774_colored_mask.npy: [0 1 3]
# Unique values in 476_colored_mask.npy: [0 1 2 3]
# Unique values in 2626_colored_mask.npy: [0 1 2 3]
# Unique values in 2982_colored_mask.npy: [0 1 3]
# Unique values in 717_colored_mask.npy: [0 1 3]
# Unique values in 2716_colored_mask.npy: [0 1 3]
# Unique values in 1473_colored_mask.npy: [0 1 3]
# Unique values in 327_colored_mask.npy: [0 1 2]
# Unique values in 1669_colored_mask.npy: [0 1 3]
# Unique values in 253_colored_mask.npy: [0 1 3]
# Unique values in 2673_colored_mask.npy: [0 1 3]
# Unique values in 1815_colored_mask.npy: [0 1 3]
# Unique values in 2643_colored_mask.npy: [0 1 2]
# Unique values in 2271_colored_mask.npy: [0 1 3]
# Unique values in 115_colored_mask.npy: [0 1 3]
# Unique values in 2517_colored_mask.npy: [0 1]
# Unique values in 1905_colored_mask.npy: [0 1 3]
# Unique values in 131_colored_mask.npy: [0 1 3]
# Unique values in 2087_colored_mask.npy: [0 1 2 3]
# Unique values in 1058_colored_mask.npy: [0 1 2 3]
# Unique values in 1498_colored_mask.npy: [0 1 2 3]
# Unique values in 1166_colored_mask.npy: [0 1 3]
# Unique values in 1812_colored_mask.npy: [0 1 3]
# Unique values in 1601_colored_mask.npy: [0 1 3]
# Unique values in 3010_colored_mask.npy: [0 1 3]
# Unique values in 626_colored_mask.npy: [0 1 3]
# Unique values in 1443_colored_mask.npy: [0 1 2 3]
# Unique values in 2174_colored_mask.npy: [0 1 2 3]
# Unique values in 2150_colored_mask.npy: [0 1 2 3]
# Unique values in 2394_colored_mask.npy: [0 1 3]
# Unique values in 5_colored_mask.npy: [0 1 3]
# Unique values in 824_colored_mask.npy: [0 1 3]
# Unique values in 366_colored_mask.npy: [0 1 3]
# Unique values in 2809_colored_mask.npy: [0 1 3]
# Unique values in 1101_colored_mask.npy: [0 1 3]
# Unique values in 850_colored_mask.npy: [0 1]
# Unique values in 2897_colored_mask.npy: [0 1 3]
# Unique values in 885_colored_mask.npy: [0 1 3]
# Unique values in 2789_colored_mask.npy: [0 1 3]
# Unique values in 1327_colored_mask.npy: [0 1 3]
# Unique values in 151_colored_mask.npy: [0 1 3]
# Unique values in 1097_colored_mask.npy: [0 1 3]
# Unique values in 2552_colored_mask.npy: [0 1 3]
# Unique values in 3011_colored_mask.npy: [0 1 3]
# Unique values in 1376_colored_mask.npy: [0 1 2 3]
# Unique values in 2655_colored_mask.npy: [0 1 2 3]
# Unique values in 3164_colored_mask.npy: [0 1 2 3]
# Unique values in 426_colored_mask.npy: [0 1 2 3]
# Unique values in 2204_colored_mask.npy: [0 1 3]
# Unique values in 732_colored_mask.npy: [0 1 3]
# Unique values in 503_colored_mask.npy: [0 1 3]
# Unique values in 1297_colored_mask.npy: [0 1 2]
# Unique values in 8_colored_mask.npy: [0 1 3]
# Unique values in 2011_colored_mask.npy: [0 1 2 3]
# Unique values in 641_colored_mask.npy: [0 1 3]
# Unique values in 892_colored_mask.npy: [0 1 3]
# Unique values in 1478_colored_mask.npy: [0 1 3]
# Unique values in 1413_colored_mask.npy: [0 1 3]
# Unique values in 1604_colored_mask.npy: [0 1 2 3]
# Unique values in 2476_colored_mask.npy: [0 1 3]
# Unique values in 2984_colored_mask.npy: [0 1 2 3]
# Unique values in 2928_colored_mask.npy: [0 1 3]
# Unique values in 2470_colored_mask.npy: [0 1 3]
# Unique values in 2608_colored_mask.npy: [0 1 3]
# Unique values in 988_colored_mask.npy: [0 1 3]
# Unique values in 622_colored_mask.npy: [0 1 2 3]
# Unique values in 1129_colored_mask.npy: [0 1 3]
# Unique values in 2501_colored_mask.npy: [0 1 2 3]
# Unique values in 2323_colored_mask.npy: [0 1 3]
# Unique values in 2627_colored_mask.npy: [0 1 3]
# Unique values in 1655_colored_mask.npy: [0 1 3]
# Unique values in 1144_colored_mask.npy: [0 1 3]
# Unique values in 260_colored_mask.npy: [0 1 3]
# Unique values in 3037_colored_mask.npy: [0 1 2 3]
# Unique values in 3243_colored_mask.npy: [0 1 2 3]
# Unique values in 2282_colored_mask.npy: [0 1 2 3]
# Unique values in 534_colored_mask.npy: [0 1 2 3]
# Unique values in 202_colored_mask.npy: [0 1 2 3]
# Unique values in 84_colored_mask.npy: [0 1 2]
# Unique values in 944_colored_mask.npy: [0 1 3]
# Unique values in 237_colored_mask.npy: [0 1 3]
# Unique values in 273_colored_mask.npy: [0 1 2 3]
# Unique values in 286_colored_mask.npy: [0 1 2 3]
# Unique values in 1032_colored_mask.npy: [0 1 3]
# Unique values in 3218_colored_mask.npy: [0 1 2]
# Unique values in 283_colored_mask.npy: [0 1 2 3]
# Unique values in 2338_colored_mask.npy: [0 1 2 3]
# Unique values in 513_colored_mask.npy: [0 1 3]
# Unique values in 766_colored_mask.npy: [0 1 3]
# Unique values in 2460_colored_mask.npy: [0 1 3]
# Unique values in 85_colored_mask.npy: [0 1 2 3]
# Unique values in 2902_colored_mask.npy: [0 1 2 3]
# Unique values in 564_colored_mask.npy: [0 1 2]
# Unique values in 359_colored_mask.npy: [0 1 3]
# Unique values in 67_colored_mask.npy: [0 1 3]
# Unique values in 2998_colored_mask.npy: [0 1 3]
# Unique values in 2725_colored_mask.npy: [0 1 3]
# Unique values in 2625_colored_mask.npy: [0 1 2 3]
# Unique values in 265_colored_mask.npy: [0 1 2 3]
# Unique values in 2505_colored_mask.npy: [0 1 3]
# Unique values in 289_colored_mask.npy: [0 1 3]
# Unique values in 2020_colored_mask.npy: [0 1 3]
# Unique values in 1125_colored_mask.npy: [0 1 3]
# Unique values in 1331_colored_mask.npy: [0 1 2 3]
# Unique values in 3242_colored_mask.npy: [0 1 2]
# Unique values in 2587_colored_mask.npy: [0 1 3]
# Unique values in 2457_colored_mask.npy: [0 1 2]
# Unique values in 2537_colored_mask.npy: [0 1 3]
# Unique values in 973_colored_mask.npy: [0 1 3]
# Unique values in 3114_colored_mask.npy: [0 1 2 3]
# Unique values in 1424_colored_mask.npy: [0 1 3]
# Unique values in 118_colored_mask.npy: [0 1 2 3]
# Unique values in 2842_colored_mask.npy: [0 1 3]
# Unique values in 2186_colored_mask.npy: [0 1 3]
# Unique values in 3030_colored_mask.npy: [0 1 3]
# Unique values in 1037_colored_mask.npy: [0 1 3]
# Unique values in 361_colored_mask.npy: [0 1 2 3]
# Unique values in 1089_colored_mask.npy: [0 1 3]
# Unique values in 1136_colored_mask.npy: [0 1 3]
# Unique values in 591_colored_mask.npy: [0 1 2 3]
# Unique values in 2091_colored_mask.npy: [0 1 3]
# Unique values in 3179_colored_mask.npy: [0 1 2 3]
# Unique values in 2890_colored_mask.npy: [0 1 3]
# Unique values in 82_colored_mask.npy: [0 1 3]
# Unique values in 1387_colored_mask.npy: [0 1 2 3]
# Unique values in 2564_colored_mask.npy: [0 1 2 3]
# Unique values in 1744_colored_mask.npy: [0 1 2]
# Unique values in 1391_colored_mask.npy: [0 1 3]
# Unique values in 1795_colored_mask.npy: [0 1 3]
# Unique values in 723_colored_mask.npy: [0 1 3]
# Unique values in 2475_colored_mask.npy: [0 1 2 3]
# Unique values in 3016_colored_mask.npy: [0 1 3]
# Unique values in 3109_colored_mask.npy: [0 1 2 3]
# Unique values in 2555_colored_mask.npy: [0 1 2]
# Unique values in 443_colored_mask.npy: [0 1 3]
# Unique values in 295_colored_mask.npy: [0 1 3]
# Unique values in 2596_colored_mask.npy: [0 1 3]
# Unique values in 3215_colored_mask.npy: [0 1 3]
# Unique values in 1134_colored_mask.npy: [0 1 3]
# Unique values in 176_colored_mask.npy: [0 1 2 3]
# Unique values in 1389_colored_mask.npy: [0 1 2 3]
# Unique values in 1475_colored_mask.npy: [0 1 2]
# Unique values in 2139_colored_mask.npy: [0 1 3]
# Unique values in 3122_colored_mask.npy: [0 1 2 3]
# Unique values in 1499_colored_mask.npy: [0 1 2 3]
# Unique values in 2993_colored_mask.npy: [0 1 2]
# Unique values in 279_colored_mask.npy: [0 1 3]
# Unique values in 2782_colored_mask.npy: [0 1 3]
# Unique values in 668_colored_mask.npy: [0 1 2]
# Unique values in 2812_colored_mask.npy: [0 1 3]
# Unique values in 757_colored_mask.npy: [0 1 3]
# Unique values in 2681_colored_mask.npy: [0 1 2 3]
# Unique values in 30_colored_mask.npy: [0 1 2 3]
# Unique values in 97_colored_mask.npy: [0 1 2 3]
# Unique values in 2417_colored_mask.npy: [0 1 3]
# Unique values in 334_colored_mask.npy: [0 1 2 3]
# Unique values in 106_colored_mask.npy: [0 1 2 3]
# Unique values in 2391_colored_mask.npy: [0 1 3]
# Unique values in 1172_colored_mask.npy: [0 1 2 3]
# Unique values in 1527_colored_mask.npy: [0 1 3]
# Unique values in 2874_colored_mask.npy: [0 1 3]
# Unique values in 2183_colored_mask.npy: [0 1 3]
# Unique values in 163_colored_mask.npy: [0 1 2 3]
# Unique values in 2386_colored_mask.npy: [0 1 2 3]
# Unique values in 113_colored_mask.npy: [0 1 3]
# Unique values in 2500_colored_mask.npy: [0 1 3]
# Unique values in 160_colored_mask.npy: [0 1 3]
# Unique values in 518_colored_mask.npy: [0 1 3]
# Unique values in 994_colored_mask.npy: [0 1 3]
# Unique values in 38_colored_mask.npy: [0 1 2 3]
# Unique values in 2228_colored_mask.npy: [0 1 2 3]
# Unique values in 2033_colored_mask.npy: [0 1 2 3]
# Unique values in 1401_colored_mask.npy: [0 1 2 3]
# Unique values in 463_colored_mask.npy: [0 1 2]
# Unique values in 490_colored_mask.npy: [0 1 3]
# Unique values in 328_colored_mask.npy: [0 1 3]
# Unique values in 2964_colored_mask.npy: [0 1 3]
# Unique values in 211_colored_mask.npy: [0 1 3]
# Unique values in 1041_colored_mask.npy: [0 1 3]
# Unique values in 811_colored_mask.npy: [0 1 2]
# Unique values in 1196_colored_mask.npy: [0 1 3]
# Unique values in 3110_colored_mask.npy: [0 1 2]
# Unique values in 2214_colored_mask.npy: [0 1 3]
# Unique values in 978_colored_mask.npy: [0 1 3]
# Unique values in 2232_colored_mask.npy: [0 1 3]
# Unique values in 1312_colored_mask.npy: [0 1 2]
# Unique values in 2495_colored_mask.npy: [0 1 2 3]
# Unique values in 3117_colored_mask.npy: [0 1 2 3]
# Unique values in 2694_colored_mask.npy: [0 1 2 3]
# Unique values in 863_colored_mask.npy: [0 1 3]
# Unique values in 2878_colored_mask.npy: [0 1 2]
# Unique values in 42_colored_mask.npy: [0 1 3]
# Unique values in 291_colored_mask.npy: [0 1 3]
# Unique values in 1778_colored_mask.npy: [0 1 3]
# Unique values in 1071_colored_mask.npy: [0 1 3]
# Unique values in 1575_colored_mask.npy: [0 1 2 3]
# Unique values in 2503_colored_mask.npy: [0 1 2]
# Unique values in 1336_colored_mask.npy: [0 1 3]
# Unique values in 2840_colored_mask.npy: [0 1 2]
# Unique values in 2869_colored_mask.npy: [0 1 3]
# Unique values in 3141_colored_mask.npy: [0 1 2 3]
# Unique values in 3202_colored_mask.npy: [0 1 3]
# Unique values in 2703_colored_mask.npy: [0 1 2 3]
# Unique values in 1569_colored_mask.npy: [0 1 3]
# Unique values in 2270_colored_mask.npy: [0 1 3]
# Unique values in 2515_colored_mask.npy: [0 1 2 3]
# Unique values in 197_colored_mask.npy: [0 1 2 3]
# Unique values in 1019_colored_mask.npy: [0 1 2 3]
# Unique values in 704_colored_mask.npy: [0 1 3]
# Unique values in 2981_colored_mask.npy: [0 1 3]
# Unique values in 630_colored_mask.npy: [0 1 2 3]
# Unique values in 33_colored_mask.npy: [0 1 3]
# Unique values in 234_colored_mask.npy: [0 1 2 3]
# Unique values in 2974_colored_mask.npy: [0 1 3]
# Unique values in 818_colored_mask.npy: [0 1 2 3]
# Unique values in 2451_colored_mask.npy: [0 1]
# Unique values in 1727_colored_mask.npy: [0 1 3]
# Unique values in 54_colored_mask.npy: [0 1 3]
# Unique values in 990_colored_mask.npy: [0 1 3]
# Unique values in 3142_colored_mask.npy: [0 1 3]
# Unique values in 2642_colored_mask.npy: [0 1 2 3]
# Unique values in 2688_colored_mask.npy: [0 1 3]
# Unique values in 672_colored_mask.npy: [0 1 3]
# Unique values in 271_colored_mask.npy: [0 1 3]
# Unique values in 683_colored_mask.npy: [0 1 2 3]
# Unique values in 251_colored_mask.npy: [0 1 3]
# Unique values in 2196_colored_mask.npy: [0 1 3]
# Unique values in 2784_colored_mask.npy: [0 1 3]
# Unique values in 759_colored_mask.npy: [0 1 3]
# Unique values in 665_colored_mask.npy: [0 1 3]
# Unique values in 2645_colored_mask.npy: [0 1 2 3]
# Unique values in 1371_colored_mask.npy: [0 1 2 3]
# Unique values in 130_colored_mask.npy: [0 1 3]
# Unique values in 1168_colored_mask.npy: [0 1 3]
# Unique values in 916_colored_mask.npy: [0 1 2 3]
# Unique values in 2925_colored_mask.npy: [0 1 3]
# Unique values in 2035_colored_mask.npy: [0 1]
# Unique values in 1677_colored_mask.npy: [0 1 3]
# Unique values in 1076_colored_mask.npy: [0 1 3]
# Unique values in 1183_colored_mask.npy: [0 1 3]
# Unique values in 1268_colored_mask.npy: [0 1 3]
# Unique values in 1603_colored_mask.npy: [0 1 2 3]
# Unique values in 951_colored_mask.npy: [0 1 2 3]
# Unique values in 589_colored_mask.npy: [0 1 3]
# Unique values in 500_colored_mask.npy: [0 1 2 3]
# Unique values in 2211_colored_mask.npy: [0 1 3]
# Unique values in 1660_colored_mask.npy: [0 1 3]
# Unique values in 156_colored_mask.npy: [0 1 2 3]
# Unique values in 2624_colored_mask.npy: [0 1 3]
# Unique values in 1118_colored_mask.npy: [0 1 3]
# Unique values in 120_colored_mask.npy: [0 1 2 3]
# Unique values in 2159_colored_mask.npy: [0 1 2 3]
# Unique values in 998_colored_mask.npy: [0 1 2 3]
# Unique values in 1592_colored_mask.npy: [0 1 2 3]
# Unique values in 2683_colored_mask.npy: [0 1 3]
# Unique values in 1108_colored_mask.npy: [0 1 2 3]
# Unique values in 456_colored_mask.npy: [0 1 3]
# Unique values in 2332_colored_mask.npy: [0 1 3]
# Unique values in 2616_colored_mask.npy: [0 1 3]
# Unique values in 35_colored_mask.npy: [0 1 2 3]
# Unique values in 1018_colored_mask.npy: [0 1 2]
# Unique values in 290_colored_mask.npy: [0 1 3]
# Unique values in 2952_colored_mask.npy: [0 1 3]
# Unique values in 61_colored_mask.npy: [0 1 2]
# Unique values in 2944_colored_mask.npy: [0 1 3]
# Unique values in 3066_colored_mask.npy: [0 1 2 3]
# Unique values in 2512_colored_mask.npy: [0 1 2 3]
# Unique values in 2051_colored_mask.npy: [0 1 3]
# Unique values in 1827_colored_mask.npy: [0 1 2 3]
# Unique values in 1873_colored_mask.npy: [0 1]
# Unique values in 3245_colored_mask.npy: [0 1 3]
# Unique values in 1078_colored_mask.npy: [0 1 3]
# Unique values in 2109_colored_mask.npy: [0 1 2 3]
# Unique values in 3077_colored_mask.npy: [0 1 3]
# Unique values in 2756_colored_mask.npy: [0 1 3]
# Unique values in 190_colored_mask.npy: [0 1 2 3]
# Unique values in 3128_colored_mask.npy: [0 1 2]
# Unique values in 2727_colored_mask.npy: [0 1 2 3]
# Unique values in 124_colored_mask.npy: [0 1 2 3]
# Unique values in 2235_colored_mask.npy: [0 1 3]
# Unique values in 1241_colored_mask.npy: [0 1 3]
# Unique values in 1191_colored_mask.npy: [0 1 3]
# Unique values in 1295_colored_mask.npy: [0 1 2]
# Unique values in 1366_colored_mask.npy: [0 1 3]
# Unique values in 2400_colored_mask.npy: [0 1 3]
# Unique values in 441_colored_mask.npy: [0 1 3]
# Unique values in 2920_colored_mask.npy: [0 1 2 3]
# Unique values in 2641_colored_mask.npy: [0 1 3]
# Unique values in 965_colored_mask.npy: [0 1 2]
# Unique values in 1067_colored_mask.npy: [0 1 2 3]
# Unique values in 1359_colored_mask.npy: [0 1 3]
# Unique values in 353_colored_mask.npy: [0 1 3]
# Unique values in 191_colored_mask.npy: [0 1 3]
# Unique values in 3226_colored_mask.npy: [0 1 3]
# Unique values in 2636_colored_mask.npy: [0 1 2 3]
# Unique values in 427_colored_mask.npy: [0 1 3]
# Unique values in 59_colored_mask.npy: [0 1 3]
# Unique values in 2294_colored_mask.npy: [0 1 2]
# Unique values in 1846_colored_mask.npy: [0 1 3]
# Unique values in 2016_colored_mask.npy: [0 1 3]
# Unique values in 2185_colored_mask.npy: [0 1 3]
# Unique values in 1200_colored_mask.npy: [0 1 2 3]
# Unique values in 604_colored_mask.npy: [0 1 3]
# Unique values in 1330_colored_mask.npy: [0 1 2 3]
# Unique values in 680_colored_mask.npy: [0 1]
# Unique values in 1820_colored_mask.npy: [0 1 2]
# Unique values in 1706_colored_mask.npy: [0 1 3]
# Unique values in 819_colored_mask.npy: [0 1 3]
# Unique values in 1944_colored_mask.npy: [0 1]
# Unique values in 595_colored_mask.npy: [0 1 2 3]
# Unique values in 379_colored_mask.npy: [0 1 2]
# Unique values in 1688_colored_mask.npy: [0 1 2]
# Unique values in 2810_colored_mask.npy: [0 1 2]
# Unique values in 1584_colored_mask.npy: [0 1 3]
# Unique values in 2697_colored_mask.npy: [0 1 2 3]
# Unique values in 1878_colored_mask.npy: [0 1 2 3]
# Unique values in 2671_colored_mask.npy: [0 1 3]
# Unique values in 2811_colored_mask.npy: [0 1 3]
# Unique values in 3148_colored_mask.npy: [0 1 3]
# Unique values in 3204_colored_mask.npy: [0 1 3]
# Unique values in 73_colored_mask.npy: [0 1 3]
# Unique values in 313_colored_mask.npy: [0 1 2]
# Unique values in 1708_colored_mask.npy: [0 1 3]
# Unique values in 2881_colored_mask.npy: [0 1 3]
# Unique values in 1123_colored_mask.npy: [0 1 3]
# Unique values in 2361_colored_mask.npy: [0 1 2 3]
# Unique values in 2650_colored_mask.npy: [0 1 2 3]
# Unique values in 1310_colored_mask.npy: [0 1 3]
# Unique values in 1738_colored_mask.npy: [0 1 3]
# Unique values in 1197_colored_mask.npy: [0 1 2]
# Unique values in 3025_colored_mask.npy: [0 1 3]
# Unique values in 871_colored_mask.npy: [0 1 3]
# Unique values in 188_colored_mask.npy: [0 1 2 3]
# Unique values in 2112_colored_mask.npy: [0 1 3]
# Unique values in 1080_colored_mask.npy: [0 1 3]
# Unique values in 98_colored_mask.npy: [0 1 3]
# Unique values in 396_colored_mask.npy: [0 1 2 3]
# Unique values in 1235_colored_mask.npy: [0 1 3]
# Unique values in 41_colored_mask.npy: [0 1 3]
# Unique values in 2850_colored_mask.npy: [0 1 2 3]
# Unique values in 2340_colored_mask.npy: [0 1 3]
# Unique values in 2257_colored_mask.npy: [0 1 3]
# Unique values in 1160_colored_mask.npy: [0 1]
# Unique values in 2730_colored_mask.npy: [0 1 3]
# Unique values in 527_colored_mask.npy: [0 1 2 3]
# Unique values in 1318_colored_mask.npy: [0 1 2 3]
# Unique values in 620_colored_mask.npy: [0 1 3]
# Unique values in 1206_colored_mask.npy: [0 1 3]
# Unique values in 2591_colored_mask.npy: [0 1 3]
# Unique values in 2541_colored_mask.npy: [0 1 3]
# Unique values in 3099_colored_mask.npy: [0 1 3]
# Unique values in 248_colored_mask.npy: [0 1 3]
# Unique values in 123_colored_mask.npy: [0 1 2 3]
# Unique values in 710_colored_mask.npy: [0 1 3]
# Unique values in 1549_colored_mask.npy: [0 1 3]
# Unique values in 230_colored_mask.npy: [0 1 3]
# Unique values in 2019_colored_mask.npy: [0 1 3]
# Unique values in 1580_colored_mask.npy: [0 1 3]
# Unique values in 580_colored_mask.npy: [0 1 3]
# Unique values in 408_colored_mask.npy: [0 1 2]
# Unique values in 3084_colored_mask.npy: [0 1 2 3]
# Unique values in 1551_colored_mask.npy: [0 1 3]
# Unique values in 1471_colored_mask.npy: [0 1 3]
# Unique values in 509_colored_mask.npy: [0 1 3]
# Unique values in 872_colored_mask.npy: [0 1 3]
# Unique values in 1629_colored_mask.npy: [0 1 3]
# Unique values in 256_colored_mask.npy: [0 1 2 3]
# Unique values in 1328_colored_mask.npy: [0 1 3]
# Unique values in 1034_colored_mask.npy: [0 1 3]
# Unique values in 1048_colored_mask.npy: [0 1 3]
# Unique values in 2352_colored_mask.npy: [0 1 3]
# Unique values in 1947_colored_mask.npy: [0 1 3]
# Unique values in 3047_colored_mask.npy: [0 1 2 3]
# Unique values in 776_colored_mask.npy: [0 1 2 3]
# Unique values in 559_colored_mask.npy: [0 1 2 3]
# Unique values in 247_colored_mask.npy: [0 1 3]
# Unique values in 1933_colored_mask.npy: [0 1 3]
# Unique values in 932_colored_mask.npy: [0 1 3]
# Unique values in 1987_colored_mask.npy: [0 1 3]
# Unique values in 362_colored_mask.npy: [0 1 3]
# Unique values in 1985_colored_mask.npy: [0 1 2]
# Unique values in 1634_colored_mask.npy: [0 1 3]
# Unique values in 60_colored_mask.npy: [0 1 2]
# Unique values in 627_colored_mask.npy: [0 1 3]
# Unique values in 1919_colored_mask.npy: [0 1 3]
# Unique values in 3012_colored_mask.npy: [0 1 3]
# Unique values in 2778_colored_mask.npy: [0 1 2 3]
# Unique values in 538_colored_mask.npy: [0 1 2 3]
# Unique values in 221_colored_mask.npy: [0 1 2]
# Unique values in 167_colored_mask.npy: [0 1 3]
# Unique values in 57_colored_mask.npy: [0 1 2 3]
# Unique values in 1289_colored_mask.npy: [0 1 3]
# Unique values in 2149_colored_mask.npy: [0 1 3]
# Unique values in 3149_colored_mask.npy: [0 1 3]
# Unique values in 515_colored_mask.npy: [0 1 3]
# Unique values in 227_colored_mask.npy: [0 1 3]
# Unique values in 1146_colored_mask.npy: [0 1 3]
# Unique values in 1095_colored_mask.npy: [0 1 3]
# Unique values in 894_colored_mask.npy: [0 1 3]
# Unique values in 690_colored_mask.npy: [0 1 2]
# Unique values in 1329_colored_mask.npy: [0 1 3]
# Unique values in 2258_colored_mask.npy: [0 1 2 3]
# Unique values in 822_colored_mask.npy: [0 1 3]
# Unique values in 2227_colored_mask.npy: [0 1 2 3]
# Unique values in 112_colored_mask.npy: [0 1 3]
# Unique values in 1762_colored_mask.npy: [0 1 2]
# Unique values in 664_colored_mask.npy: [0 1 2]
# Unique values in 938_colored_mask.npy: [0 1 2 3]
# Unique values in 372_colored_mask.npy: [0 1 3]
# Unique values in 2458_colored_mask.npy: [0 1 2]
# Unique values in 388_colored_mask.npy: [0 1 2 3]
# Unique values in 3054_colored_mask.npy: [0 1 3]
# Unique values in 478_colored_mask.npy: [0 1 3]
# Unique values in 193_colored_mask.npy: [0 1 2 3]
# Unique values in 639_colored_mask.npy: [0 1 3]
# Unique values in 2166_colored_mask.npy: [0 1 2 3]
# Unique values in 452_colored_mask.npy: [0 1 3]
# Unique values in 152_colored_mask.npy: [0 1 3]
# Unique values in 1534_colored_mask.npy: [0 1 2]
# Unique values in 368_colored_mask.npy: [0 1 2]
# Unique values in 1955_colored_mask.npy: [0 1 3]
# Unique values in 2614_colored_mask.npy: [0 1 2]
# Unique values in 2612_colored_mask.npy: [0 1 3]
# Unique values in 2224_colored_mask.npy: [0 1]
# Unique values in 1440_colored_mask.npy: [0 1 3]
# Unique values in 1044_colored_mask.npy: [0 1 2 3]
# Unique values in 2488_colored_mask.npy: [0 1 3]
# Unique values in 1496_colored_mask.npy: [0 1 2 3]
# Unique values in 745_colored_mask.npy: [0 1 2 3]
# Unique values in 738_colored_mask.npy: [0 1 2 3]
# Unique values in 2662_colored_mask.npy: [0 1 3]
# Unique values in 2436_colored_mask.npy: [0 1 3]
# Unique values in 2859_colored_mask.npy: [0 1 3]
# Unique values in 1836_colored_mask.npy: [0 1 2 3]
# Unique values in 506_colored_mask.npy: [0 1 3]
# Unique values in 1854_colored_mask.npy: [0 1]
# Unique values in 3108_colored_mask.npy: [0 1 2 3]
# Unique values in 1737_colored_mask.npy: [0 1 3]
# Unique values in 2221_colored_mask.npy: [0 1 3]
# Unique values in 1735_colored_mask.npy: [0 1 3]
# Unique values in 1434_colored_mask.npy: [0 1 3]
# Unique values in 192_colored_mask.npy: [0 1 2 3]
# Unique values in 2411_colored_mask.npy: [0 1 2 3]
# Unique values in 412_colored_mask.npy: [0 1 2]
# Unique values in 1865_colored_mask.npy: [0 1 3]
# Unique values in 3129_colored_mask.npy: [0 1 2 3]
# Unique values in 3006_colored_mask.npy: [0 1 2 3]
# Unique values in 1099_colored_mask.npy: [0 1 3]
# Unique values in 1082_colored_mask.npy: [0 1 3]
# Unique values in 3169_colored_mask.npy: [0 1 2 3]
# Unique values in 2589_colored_mask.npy: [0 1 3]
# Unique values in 2331_colored_mask.npy: [0 1 2]
# Unique values in 3082_colored_mask.npy: [0 1 2 3]
# Unique values in 2036_colored_mask.npy: [0 1 3]
# Unique values in 91_colored_mask.npy: [0 1 3]
# Unique values in 1054_colored_mask.npy: [0 1 3]
# Unique values in 1017_colored_mask.npy: [0 1 2]
# Unique values in 653_colored_mask.npy: [0 1 2]
# Unique values in 3166_colored_mask.npy: [0 1 3]
# Unique values in 1406_colored_mask.npy: [0 1 3]
# Unique values in 1649_colored_mask.npy: [0 1 2]
# Unique values in 9_colored_mask.npy: [0 1 3]
# Unique values in 705_colored_mask.npy: [0 1 3]
# Unique values in 101_colored_mask.npy: [0 1 3]
# Unique values in 1963_colored_mask.npy: [0 1]
# Unique values in 1372_colored_mask.npy: [0 1 3]
# Unique values in 2740_colored_mask.npy: [0 1 3]
# Unique values in 2077_colored_mask.npy: [0 1 3]
# Unique values in 1733_colored_mask.npy: [0 1 3]
# Unique values in 2714_colored_mask.npy: [0 1 3]
# Unique values in 2664_colored_mask.npy: [0 1 3]
# Unique values in 651_colored_mask.npy: [0 1 2 3]
# Unique values in 2123_colored_mask.npy: [0 1 2 3]
# Unique values in 1544_colored_mask.npy: [0 1 3]
# Unique values in 1324_colored_mask.npy: [0 1 3]
# Unique values in 2886_colored_mask.npy: [0 1 2]
# Unique values in 2705_colored_mask.npy: [0 1 2 3]
# Unique values in 2099_colored_mask.npy: [0 1 3]
# Unique values in 3184_colored_mask.npy: [0 1 3]
# Unique values in 99_colored_mask.npy: [0 1 3]
# Unique values in 2155_colored_mask.npy: [0 1 2 3]
# Unique values in 1563_colored_mask.npy: [0 1]
# Unique values in 382_colored_mask.npy: [0 1 2]
# Unique values in 1523_colored_mask.npy: [0 1 3]
# Unique values in 3201_colored_mask.npy: [0 1 2 3]
# Unique values in 836_colored_mask.npy: [0 1 3]
# Unique values in 2255_colored_mask.npy: [0 1 2]
# Unique values in 1259_colored_mask.npy: [0 1 2 3]
# Unique values in 2793_colored_mask.npy: [0 1 2]
# Unique values in 1547_colored_mask.npy: [0 1 3]
# Unique values in 241_colored_mask.npy: [0 1 2 3]
# Unique values in 832_colored_mask.npy: [0 1 3]
# Unique values in 2310_colored_mask.npy: [0 1 2 3]
# Unique values in 1557_colored_mask.npy: [0 1 2 3]
# Unique values in 397_colored_mask.npy: [0 1 2 3]
# Unique values in 3158_colored_mask.npy: [0 1 2 3]
# Unique values in 37_colored_mask.npy: [0 1 2]
# Unique values in 2117_colored_mask.npy: [0 1 3]
# Unique values in 2518_colored_mask.npy: [0 1 3]
# Unique values in 340_colored_mask.npy: [0 1 2 3]
# Unique values in 435_colored_mask.npy: [0 1 3]
# Unique values in 2023_colored_mask.npy: [0 1 2 3]
# Unique values in 2063_colored_mask.npy: [0 1 3]
# Unique values in 2046_colored_mask.npy: [0 1 3]
# Unique values in 2692_colored_mask.npy: [0 1 3]
# Unique values in 524_colored_mask.npy: [0 1 3]
# Unique values in 3005_colored_mask.npy: [0 1 3]
# Unique values in 1764_colored_mask.npy: [0 1 3]
# Unique values in 2116_colored_mask.npy: [0 1 3]
# Unique values in 1060_colored_mask.npy: [0 1 3]
# Unique values in 1126_colored_mask.npy: [0 1 3]
# Unique values in 2010_colored_mask.npy: [0 1 3]
# Unique values in 1642_colored_mask.npy: [0 1 3]
# Unique values in 3147_colored_mask.npy: [0 1 2 3]
# Unique values in 529_colored_mask.npy: [0 1 3]
# Unique values in 2393_colored_mask.npy: [0 1 2 3]
# Unique values in 2360_colored_mask.npy: [0 1 3]
# Unique values in 177_colored_mask.npy: [0 1 2 3]
# Unique values in 2876_colored_mask.npy: [0 1 3]
# Unique values in 2864_colored_mask.npy: [0 1 2 3]
# Unique values in 2296_colored_mask.npy: [0 1 3]
# Unique values in 868_colored_mask.npy: [0 1 2 3]
# Unique values in 186_colored_mask.npy: [0 1 3]
# Unique values in 1718_colored_mask.npy: [0 1 2]
# Unique values in 2462_colored_mask.npy: [0 1 2 3]
# Unique values in 2605_colored_mask.npy: [0 1 3]
# Unique values in 720_colored_mask.npy: [0 1 3]
# Unique values in 1494_colored_mask.npy: [0 1 2 3]
# Unique values in 3086_colored_mask.npy: [0 1 3]
# Unique values in 2620_colored_mask.npy: [0 1 3]
# Unique values in 1967_colored_mask.npy: [0 1 3]
# Unique values in 358_colored_mask.npy: [0 1 2 3]
# Unique values in 1378_colored_mask.npy: [0 1 3]
# Unique values in 468_colored_mask.npy: [0 1 3]
# Unique values in 2678_colored_mask.npy: [0 1 3]
# Unique values in 75_colored_mask.npy: [0 1 2 3]
# Unique values in 1507_colored_mask.npy: [0 1 2]
# Unique values in 1980_colored_mask.npy: [0 1 2 3]
# Unique values in 1913_colored_mask.npy: [0 1 2 3]
# Unique values in 1315_colored_mask.npy: [0 1 2 3]
# Unique values in 963_colored_mask.npy: [0 1 3]
# Unique values in 1503_colored_mask.npy: [0 1 2]
# Unique values in 1287_colored_mask.npy: [0 1 3]
# Unique values in 943_colored_mask.npy: [0 1 3]
# Unique values in 403_colored_mask.npy: [0 1 2]
# Unique values in 1145_colored_mask.npy: [0 1 3]
# Unique values in 3103_colored_mask.npy: [0 1 2 3]
# Unique values in 660_colored_mask.npy: [0 1 2 3]
# Unique values in 1281_colored_mask.npy: [0 1 3]
# Unique values in 3199_colored_mask.npy: [0 1 2 3]
# Unique values in 928_colored_mask.npy: [0 1 3]
# Unique values in 1180_colored_mask.npy: [0 1 3]
# Unique values in 2477_colored_mask.npy: [0 1 3]
# Unique values in 1335_colored_mask.npy: [0 1 3]
# Unique values in 2300_colored_mask.npy: [0 1 3]
# Unique values in 2447_colored_mask.npy: [0 1 2 3]
# Unique values in 117_colored_mask.npy: [0 1 2 3]
# Unique values in 2962_colored_mask.npy: [0 1 3]
# Unique values in 1935_colored_mask.npy: [0 1 3]
# Unique values in 81_colored_mask.npy: [0 1 2 3]
# Unique values in 1352_colored_mask.npy: [0 1 3]
# Unique values in 1646_colored_mask.npy: [0 1 2]
# Unique values in 721_colored_mask.npy: [0 1 3]
# Unique values in 974_colored_mask.npy: [0 1 2 3]
# Unique values in 1514_colored_mask.npy: [0 1 3]
# Unique values in 2459_colored_mask.npy: [0 1 3]
# Unique values in 2239_colored_mask.npy: [0 1 3]
# Unique values in 684_colored_mask.npy: [0 1 3]
# Unique values in 1122_colored_mask.npy: [0 1 3]
# Unique values in 390_colored_mask.npy: [0 1 2 3]
# Unique values in 299_colored_mask.npy: [0 1 3]
# Unique values in 2176_colored_mask.npy: [0 1 3]
# Unique values in 410_colored_mask.npy: [0 1 3]
# Unique values in 381_colored_mask.npy: [0 1]
# Unique values in 535_colored_mask.npy: [0 1 3]
# Unique values in 494_colored_mask.npy: [0 1 3]
# Unique values in 1053_colored_mask.npy: [0 1 2 3]
# Unique values in 2110_colored_mask.npy: [0 1 3]
# Unique values in 481_colored_mask.npy: [0 1 2 3]
# Unique values in 401_colored_mask.npy: [0 1 3]
# Unique values in 3200_colored_mask.npy: [0 1 2 3]
# Unique values in 2002_colored_mask.npy: [0 1 3]
# Unique values in 1462_colored_mask.npy: [0 1 3]
# Unique values in 2834_colored_mask.npy: [0 1 2 3]
# Unique values in 2996_colored_mask.npy: [0 1 2]
# Unique values in 2790_colored_mask.npy: [0 1 3]
# Unique values in 2938_colored_mask.npy: [0 1 3]
# Unique values in 1911_colored_mask.npy: [0 1 3]
# Unique values in 1543_colored_mask.npy: [0 1 3]
# Unique values in 2745_colored_mask.npy: [0 1 2 3]
# Unique values in 2825_colored_mask.npy: [0 1 2 3]
# Unique values in 1487_colored_mask.npy: [0 1 2 3]
# Unique values in 774_colored_mask.npy: [0 1 3]
# Unique values in 1077_colored_mask.npy: [0 1 3]
# Unique values in 2040_colored_mask.npy: [0 1]
# Unique values in 2362_colored_mask.npy: [0 1 3]
# Unique values in 1156_colored_mask.npy: [0 1 3]
# Unique values in 864_colored_mask.npy: [0 1 3]
# Unique values in 276_colored_mask.npy: [0 1 3]
# Unique values in 46_colored_mask.npy: [0 1 3]
# Unique values in 1690_colored_mask.npy: [0 1 3]
# Unique values in 2758_colored_mask.npy: [0 1 2 3]
# Unique values in 560_colored_mask.npy: [0 1 3]
# Unique values in 3023_colored_mask.npy: [0 1 3]
# Unique values in 319_colored_mask.npy: [0 1 3]
# Unique values in 3180_colored_mask.npy: [0 1 3]
# Unique values in 2496_colored_mask.npy: [0 1 3]
# Unique values in 2957_colored_mask.npy: [0 1 2 3]
# Unique values in 903_colored_mask.npy: [0 1 2 3]
# Unique values in 2318_colored_mask.npy: [0 1 3]
# Unique values in 1502_colored_mask.npy: [0 1 3]
# Unique values in 1901_colored_mask.npy: [0 1 2 3]
# Unique values in 525_colored_mask.npy: [0 1 2 3]
# Unique values in 1875_colored_mask.npy: [0 1 3]
# Unique values in 3113_colored_mask.npy: [0 1 3]
# Unique values in 3088_colored_mask.npy: [0 1 2 3]
# Unique values in 1457_colored_mask.npy: [0 1 3]
# Unique values in 455_colored_mask.npy: [0 1 3]
# Unique values in 1638_colored_mask.npy: [0 1 3]
# Unique values in 2534_colored_mask.npy: [0 1 2 3]
# Unique values in 1148_colored_mask.npy: [0 1 3]
# Unique values in 2005_colored_mask.npy: [0 1 3]
# Unique values in 2241_colored_mask.npy: [0 1 2 3]
# Unique values in 2483_colored_mask.npy: [0 1 3]
# Unique values in 2412_colored_mask.npy: [0 1 3]
# Unique values in 3036_colored_mask.npy: [0 1 2]
# Unique values in 2247_colored_mask.npy: [0 1 2 3]
# Unique values in 1784_colored_mask.npy: [0 1 2]
# Unique values in 905_colored_mask.npy: [0 1 3]
# Unique values in 1405_colored_mask.npy: [0 1 3]
# Unique values in 2418_colored_mask.npy: [0 1 2 3]
# Unique values in 267_colored_mask.npy: [0 1 2 3]
# Unique values in 2791_colored_mask.npy: [0 1 3]
# Unique values in 1510_colored_mask.npy: [0 1 3]
# Unique values in 1466_colored_mask.npy: [0 1 3]
# Unique values in 1364_colored_mask.npy: [0 1 3]
# Unique values in 1839_colored_mask.npy: [0 1 3]
# Unique values in 2222_colored_mask.npy: [0 1 3]
# Unique values in 1824_colored_mask.npy: [0 1 2 3]
# Unique values in 2218_colored_mask.npy: [0 1 3]
# Unique values in 2245_colored_mask.npy: [0 1 2]
# Unique values in 1497_colored_mask.npy: [0 1 3]
# Unique values in 2903_colored_mask.npy: [0 1 3]
# Unique values in 2238_colored_mask.npy: [0 1 3]
# Unique values in 1518_colored_mask.npy: [0 1 3]
# Unique values in 1431_colored_mask.npy: [0 1 3]
# Unique values in 2487_colored_mask.npy: [0 1 2 3]
# Unique values in 561_colored_mask.npy: [0 1 2 3]
# Unique values in 563_colored_mask.npy: [0 1 3]
# Unique values in 65_colored_mask.npy: [0 1 3]
# Unique values in 2065_colored_mask.npy: [0 1 3]
# Unique values in 3220_colored_mask.npy: [0 1 3]
# Unique values in 1286_colored_mask.npy: [0 1 3]
# Unique values in 467_colored_mask.npy: [0 1 3]
# Unique values in 530_colored_mask.npy: [0 1 2 3]
# Unique values in 127_colored_mask.npy: [0 1 3]
# Unique values in 1029_colored_mask.npy: [0 1 3]
# Unique values in 196_colored_mask.npy: [0 1 3]
# Unique values in 2978_colored_mask.npy: [0 1 2]
# Unique values in 3135_colored_mask.npy: [0 1 2]
# Unique values in 2142_colored_mask.npy: [0 1 3]
# Unique values in 2225_colored_mask.npy: [0 1 3]
# Unique values in 140_colored_mask.npy: [0 1 3]
# Unique values in 1042_colored_mask.npy: [0 1 3]
# Unique values in 531_colored_mask.npy: [0 1 3]
# Unique values in 235_colored_mask.npy: [0 1 2 3]
# Unique values in 2440_colored_mask.npy: [0 1 2]
# Unique values in 3007_colored_mask.npy: [0 1 3]
# Unique values in 2140_colored_mask.npy: [0 1 2 3]
# Unique values in 2601_colored_mask.npy: [0 1 3]
# Unique values in 2075_colored_mask.npy: [0 1 2]
# Unique values in 1876_colored_mask.npy: [0 1 2 3]
# Unique values in 1545_colored_mask.npy: [0 1 2 3]
# Unique values in 713_colored_mask.npy: [0 1 3]
# Unique values in 2551_colored_mask.npy: [0 1 3]
# Unique values in 1639_colored_mask.npy: [0 1 3]
# Unique values in 2479_colored_mask.npy: [0 1 3]
# Unique values in 826_colored_mask.npy: [0 1 3]
# Unique values in 415_colored_mask.npy: [0 1 3]
# Unique values in 1266_colored_mask.npy: [0 1 2 3]
# Unique values in 2047_colored_mask.npy: [0 1 3]
# Unique values in 482_colored_mask.npy: [0 1 3]
# Unique values in 1595_colored_mask.npy: [0 1 3]
# Unique values in 2909_colored_mask.npy: [0 1]
# Unique values in 1533_colored_mask.npy: [0 1 2]
# Unique values in 3165_colored_mask.npy: [0 1 3]
# Unique values in 2450_colored_mask.npy: [0 1 3]
# Unique values in 322_colored_mask.npy: [0 1 3]
# Unique values in 79_colored_mask.npy: [0 1 3]
# Unique values in 878_colored_mask.npy: [0 1 2 3]
# Unique values in 2817_colored_mask.npy: [0 1 2 3]
# Unique values in 1605_colored_mask.npy: [0 1 3]
# Unique values in 1093_colored_mask.npy: [0 1 2 3]
# Unique values in 2755_colored_mask.npy: [0 1 3]
# Unique values in 2709_colored_mask.npy: [0 1 2 3]
# Unique values in 2406_colored_mask.npy: [0 1 3]
# Unique values in 302_colored_mask.npy: [0 1 2 3]
# Unique values in 3009_colored_mask.npy: [0 1 3]
# Unique values in 1423_colored_mask.npy: [0 1 3]
# Unique values in 2594_colored_mask.npy: [0 1 2 3]
# Unique values in 2914_colored_mask.npy: [0 1 3]
# Unique values in 2839_colored_mask.npy: [0 1 3]
# Unique values in 1954_colored_mask.npy: [0 1 3]
# Unique values in 179_colored_mask.npy: [0 1 2 3]
# Unique values in 2898_colored_mask.npy: [0 1 3]
# Unique values in 1299_colored_mask.npy: [0 1 3]
# Unique values in 1261_colored_mask.npy: [0 1 3]
# Unique values in 1313_colored_mask.npy: [0 1 2 3]
# Unique values in 1528_colored_mask.npy: [0 1 3]
# Unique values in 3219_colored_mask.npy: [0 1 2 3]
# Unique values in 2056_colored_mask.npy: [0 1 3]
# Unique values in 284_colored_mask.npy: [0 1 3]
# Unique values in 2259_colored_mask.npy: [0 1 3]
# Unique values in 419_colored_mask.npy: [0 1 3]
# Unique values in 3106_colored_mask.npy: [0 1 2]
# Unique values in 2967_colored_mask.npy: [0 1 2 3]
# Unique values in 1964_colored_mask.npy: [0 1 2]
# Unique values in 2565_colored_mask.npy: [0 1 3]
# Unique values in 2644_colored_mask.npy: [0 1 3]
# Unique values in 2693_colored_mask.npy: [0 1 3]
# Unique values in 2456_colored_mask.npy: [0 1 3]
# Unique values in 285_colored_mask.npy: [0 1 2 3]
# Unique values in 1430_colored_mask.npy: [0 1 3]
# Unique values in 1038_colored_mask.npy: [0 1 2 3]
# Unique values in 3123_colored_mask.npy: [0 1 3]
# Unique values in 3157_colored_mask.npy: [0 1 3]
# Unique values in 387_colored_mask.npy: [0 1 3]
# Unique values in 1353_colored_mask.npy: [0 1 2 3]
# Unique values in 590_colored_mask.npy: [0 1 2 3]
# Unique values in 2843_colored_mask.npy: [0 1 3]
# Unique values in 3039_colored_mask.npy: [0 1 2 3]
# Unique values in 1928_colored_mask.npy: [0 1 2 3]
# Unique values in 2468_colored_mask.npy: [0 1 3]
# Unique values in 1039_colored_mask.npy: [0 1 3]
# Unique values in 2590_colored_mask.npy: [0 1 3]
# Unique values in 105_colored_mask.npy: [0 1 3]
# Unique values in 846_colored_mask.npy: [0 1]
# Unique values in 929_colored_mask.npy: [0 1 3]
# Unique values in 2329_colored_mask.npy: [0 1 3]
# Unique values in 897_colored_mask.npy: [0 1 3]
# Unique values in 1132_colored_mask.npy: [0 1 3]
# Unique values in 2243_colored_mask.npy: [0 1 2 3]
# Unique values in 649_colored_mask.npy: [0 1 2]
# Unique values in 2845_colored_mask.npy: [0 1 2]
# Unique values in 1793_colored_mask.npy: [0 1 3]
# Unique values in 1558_colored_mask.npy: [0 1 3]
# Unique values in 1672_colored_mask.npy: [0 1 3]
# Unique values in 3225_colored_mask.npy: [0 1 3]
# Unique values in 2396_colored_mask.npy: [0 1 3]
# Unique values in 111_colored_mask.npy: [0 1 2 3]
# Unique values in 3173_colored_mask.npy: [0 1 2 3]
# Unique values in 634_colored_mask.npy: [0 1 3]
# Unique values in 856_colored_mask.npy: [0 1 3]
# Unique values in 1203_colored_mask.npy: [0 1 2 3]
# Unique values in 2348_colored_mask.npy: [0 1 3]
# Unique values in 2929_colored_mask.npy: [0 1 3]
# Unique values in 1133_colored_mask.npy: [0 1 3]
# Unique values in 1158_colored_mask.npy: [0 1 3]
# Unique values in 1816_colored_mask.npy: [0 1 2 3]
# Unique values in 3015_colored_mask.npy: [0 1 3]
# Unique values in 619_colored_mask.npy: [0 1 2 3]
# Unique values in 2808_colored_mask.npy: [0 1 3]
# Unique values in 356_colored_mask.npy: [0 1 2 3]
# Unique values in 3229_colored_mask.npy: [0 1 2 3]
# Unique values in 145_colored_mask.npy: [0 1 3]
# Unique values in 2425_colored_mask.npy: [0 1 2 3]
# Unique values in 2799_colored_mask.npy: [0 1 2 3]
# Unique values in 1860_colored_mask.npy: [0 1 3]
# Unique values in 1217_colored_mask.npy: [0 1 3]
# Unique values in 1254_colored_mask.npy: [0 1 3]
# Unique values in 2717_colored_mask.npy: [0 1 3]
# Unique values in 611_colored_mask.npy: [0 1 3]
# Unique values in 2955_colored_mask.npy: [0 1 3]
# Unique values in 3194_colored_mask.npy: [0 1 2 3]
# Unique values in 758_colored_mask.npy: [0 1 3]
# Unique values in 2656_colored_mask.npy: [0 1 3]
# Unique values in 920_colored_mask.npy: [0 1 3]
# Unique values in 135_colored_mask.npy: [0 1 2 3]
# Unique values in 2677_colored_mask.npy: [0 1 2 3]
# Unique values in 2670_colored_mask.npy: [0 1 3]
# Unique values in 2942_colored_mask.npy: [0 1 3]
# Unique values in 3065_colored_mask.npy: [0 1 3]
# Unique values in 1978_colored_mask.npy: [0 1 3]
# Unique values in 3186_colored_mask.npy: [0 1 3]
# Unique values in 246_colored_mask.npy: [0 1 3]
# Unique values in 3251_colored_mask.npy: [0 1 3]
# Unique values in 2401_colored_mask.npy: [0 1 2 3]
# Unique values in 1489_colored_mask.npy: [0 1 3]
# Unique values in 1668_colored_mask.npy: [0 1 3]
# Unique values in 3182_colored_mask.npy: [0 1 3]
# Unique values in 1109_colored_mask.npy: [0 1 3]
# Unique values in 2184_colored_mask.npy: [0 1 2 3]
# Unique values in 541_colored_mask.npy: [0 1 3]
# Unique values in 2803_colored_mask.npy: [0 1 2 3]
# Unique values in 3027_colored_mask.npy: [0 1 3]
# Unique values in 2915_colored_mask.npy: [0 1 3]
# Unique values in 2887_colored_mask.npy: [0 1 3]
# Unique values in 1540_colored_mask.npy: [0 1 3]
# Unique values in 2917_colored_mask.npy: [0 1 2 3]
# Unique values in 2736_colored_mask.npy: [0 1 3]
# Unique values in 1074_colored_mask.npy: [0 1 3]
# Unique values in 2102_colored_mask.npy: [0 1 2 3]
# Unique values in 2584_colored_mask.npy: [0 1 3]
# Unique values in 548_colored_mask.npy: [0 1 3]
# Unique values in 1421_colored_mask.npy: [0 1 3]
# Unique values in 3078_colored_mask.npy: [0 1 2 3]
# Unique values in 434_colored_mask.npy: [0 1 3]
# Unique values in 876_colored_mask.npy: [0 1 2 3]
# Unique values in 1181_colored_mask.npy: [0 1 2 3]
# Unique values in 214_colored_mask.npy: [0 1]
# Unique values in 1556_colored_mask.npy: [0 1 2 3]
# Unique values in 699_colored_mask.npy: [0 1 2 3]
# Unique values in 225_colored_mask.npy: [0 1 2 3]
# Unique values in 1572_colored_mask.npy: [0 1 3]
# Unique values in 3203_colored_mask.npy: [0 1 3]
# Unique values in 1787_colored_mask.npy: [0 1 3]
# Unique values in 2428_colored_mask.npy: [0 1 3]
# Unique values in 2771_colored_mask.npy: [0 1 2 3]
# Unique values in 3196_colored_mask.npy: [0 1 2 3]
# Unique values in 3205_colored_mask.npy: [0 1 2 3]
# Unique values in 252_colored_mask.npy: [0 1 2 3]
# Unique values in 765_colored_mask.npy: [0 1 3]
# Unique values in 77_colored_mask.npy: [0 1 3]
# Unique values in 3227_colored_mask.npy: [0 1 2 3]
# Unique values in 1916_colored_mask.npy: [0 1 2]
# Unique values in 1897_colored_mask.npy: [0 1 3]
# Unique values in 763_colored_mask.npy: [0 1 2 3]
# Unique values in 166_colored_mask.npy: [0 1 3]
# Unique values in 292_colored_mask.npy: [0 1 3]
# Unique values in 1225_colored_mask.npy: [0 1 3]
# Unique values in 2931_colored_mask.npy: [0 1 2 3]
# Unique values in 1151_colored_mask.npy: [0 1 3]
# Unique values in 1613_colored_mask.npy: [0 1]
# Unique values in 1632_colored_mask.npy: [0 1 3]
# Unique values in 2177_colored_mask.npy: [0 1 3]
# Unique values in 466_colored_mask.npy: [0 1 2 3]
# Unique values in 2653_colored_mask.npy: [0 1 3]
# Unique values in 159_colored_mask.npy: [0 1 3]
# Unique values in 1730_colored_mask.npy: [0 1 3]
# Unique values in 1450_colored_mask.npy: [0 1 3]
# Unique values in 1570_colored_mask.npy: [0 1 3]
# Unique values in 464_colored_mask.npy: [0 1 3]
# ...
# Unique values in 470_colored_mask.npy: [0 1 3]
# Unique values in 2865_colored_mask.npy: [0 1 3]
# Unique values in 2946_colored_mask.npy: [0 1 2]
# Unique values in 2507_colored_mask.npy: [0 1 2 3]
# Unique values in 1441_colored_mask.npy: [0 1 2 3]
# Unique values in 1720_colored_mask.npy: [0 1 3]
# Unique values in 170_colored_mask.npy: [0 1 2 3]
# Unique values in 3020_colored_mask.npy: [0 1 3]
# Unique values in 2593_colored_mask.npy: [0 1 2 3]
# Unique values in 983_colored_mask.npy: [0 1 3]
# Unique values in 707_colored_mask.npy: [0 1]
# Unique values in 2519_colored_mask.npy: [0 1 3]
# Unique values in 2776_colored_mask.npy: [0 1 2 3]
# Unique values in 428_colored_mask.npy: [0 1 3]
# Unique values in 1852_colored_mask.npy: [0 1 2]
# Unique values in 3132_colored_mask.npy: [0 1 2 3]
# Unique values in 1456_colored_mask.npy: [0 1 2 3]
# Unique values in 1653_colored_mask.npy: [0 1 3]
# Unique values in 1193_colored_mask.npy: [0 1 2 3]
# Unique values in 3171_colored_mask.npy: [0 1 3]
# Unique values in 1806_colored_mask.npy: [0 1 3]
# Unique values in 1065_colored_mask.npy: [0 1 3]
# Unique values in 324_colored_mask.npy: [0 1 3]
# Unique values in 2818_colored_mask.npy: [0 1 3]
# Unique values in 1609_colored_mask.npy: [0 1 2 3]
# Unique values in 1739_colored_mask.npy: [0 1 2 3]
# Unique values in 2381_colored_mask.npy: [0 1 3]
# Unique values in 2106_colored_mask.npy: [0 1 3]
# Unique values in 2493_colored_mask.npy: [0 1 2 3]
# Unique values in 457_colored_mask.npy: [0 1 2 3]
# Unique values in 803_colored_mask.npy: [0 1 3]
# Unique values in 1530_colored_mask.npy: [0 1 2]
# Unique values in 2583_colored_mask.npy: [0 1 2 3]
# Unique values in 2617_colored_mask.npy: [0 1 2 3]
# Unique values in 2358_colored_mask.npy: [0 1 3]
# Unique values in 689_colored_mask.npy: [0 1 2 3]
# Unique values in 2007_colored_mask.npy: [0 1 3]
# Unique values in 1115_colored_mask.npy: [0 1 2]
# Unique values in 2206_colored_mask.npy: [0 1 3]
# Unique values in 1377_colored_mask.npy: [0 1 2 3]
# Unique values in 14_colored_mask.npy: [0 1 2 3]
# Unique values in 1284_colored_mask.npy: [0 1 3]
# Unique values in 2926_colored_mask.npy: [0 1 3]
# Unique values in 1965_colored_mask.npy: [0 1 2 3]
# Unique values in 549_colored_mask.npy: [0 1 3]
# Unique values in 2729_colored_mask.npy: [0 1 3]
# Unique values in 2647_colored_mask.npy: [0 1 3]
# Unique values in 1602_colored_mask.npy: [0 1 3]
# Unique values in 2916_colored_mask.npy: [0 1 3]
# Unique values in 1357_colored_mask.npy: [0 1 3]
# Unique values in 860_colored_mask.npy: [0 1 2 3]
# Unique values in 2577_colored_mask.npy: [0 1 2 3]
# Unique values in 2956_colored_mask.npy: [0 1 2 3]
# Unique values in 2069_colored_mask.npy: [0 1 3]
# Unique values in 2765_colored_mask.npy: [0 1 3]
# Unique values in 2904_colored_mask.npy: [0 1 3]
# Unique values in 1537_colored_mask.npy: [0 1 2 3]
# Unique values in 1226_colored_mask.npy: [0 1 3]
# Unique values in 2062_colored_mask.npy: [0 1 3]
# Unique values in 2355_colored_mask.npy: [0 1 2 3]
# Unique values in 18_colored_mask.npy: [0 1 3]
# Unique values in 697_colored_mask.npy: [0 1 3]
# Unique values in 2045_colored_mask.npy: [0 1]
# Unique values in 175_colored_mask.npy: [0 1 3]
# Unique values in 3170_colored_mask.npy: [0 1 3]
# Unique values in 268_colored_mask.npy: [0 1 2 3]
# Unique values in 2989_colored_mask.npy: [0 1 3]
# Unique values in 2768_colored_mask.npy: [0 1 3]
# Unique values in 2432_colored_mask.npy: [0 1 2]
# Unique values in 517_colored_mask.npy: [0 1 3]
# Unique values in 1276_colored_mask.npy: [0 1 2 3]
# Unique values in 2147_colored_mask.npy: [0 1 2]
# Unique values in 953_colored_mask.npy: [0 1 3]
# Unique values in 960_colored_mask.npy: [0 1 3]
# Unique values in 526_colored_mask.npy: [0 1 3]
# Unique values in 1741_colored_mask.npy: [0 1 3]
# Unique values in 607_colored_mask.npy: [0 1 2 3]
# Unique values in 1229_colored_mask.npy: [0 1 3]
# Unique values in 226_colored_mask.npy: [0 1 3]
# Unique values in 1052_colored_mask.npy: [0 1 2 3]
# Unique values in 3081_colored_mask.npy: [0 1 2]
# Unique values in 1553_colored_mask.npy: [0 1 3]
# Unique values in 3061_colored_mask.npy: [0 1 3]
# Unique values in 1338_colored_mask.npy: [0 1 3]
# Unique values in 1641_colored_mask.npy: [0 1 3]
# Unique values in 740_colored_mask.npy: [0 1 3]
# Unique values in 2484_colored_mask.npy: [0 1 3]
# Unique values in 3211_colored_mask.npy: [0 1 2 3]
# Unique values in 1317_colored_mask.npy: [0 1 3]
# Unique values in 1525_colored_mask.npy: [0 1 2 3]
# Unique values in 637_colored_mask.npy: [0 1 2]
# Unique values in 462_colored_mask.npy: [0 1 3]
# Unique values in 3055_colored_mask.npy: [0 1 2 3]
# Unique values in 3100_colored_mask.npy: [0 1 3]
# Unique values in 1509_colored_mask.npy: [0 1 3]
# Unique values in 116_colored_mask.npy: [0 1 3]
# Unique values in 2446_colored_mask.npy: [0 1 3]
# Unique values in 1969_colored_mask.npy: [0 1 2]
# Unique values in 2287_colored_mask.npy: [0 1 3]
# Unique values in 2015_colored_mask.npy: [0 1 2 3]
# Unique values in 2467_colored_mask.npy: [0 1 2]
# Unique values in 2053_colored_mask.npy: [0 1 3]
# Unique values in 898_colored_mask.npy: [0 1 3]
# Unique values in 2383_colored_mask.npy: [0 1 2]
# Unique values in 1111_colored_mask.npy: [0 1 2]
# Unique values in 985_colored_mask.npy: [0 1 3]
# Unique values in 1516_colored_mask.npy: [0 1 3]
# Unique values in 1195_colored_mask.npy: [0 1 2 3]
# Unique values in 1752_colored_mask.npy: [0 1 3]
# Unique values in 1633_colored_mask.npy: [0 1 2 3]
# Unique values in 2337_colored_mask.npy: [0 1 3]
# Unique values in 3152_colored_mask.npy: [0 1 2 3]
# Unique values in 3159_colored_mask.npy: [0 1 3]
# Unique values in 1367_colored_mask.npy: [0 1 2 3]
# Unique values in 2494_colored_mask.npy: [0 1 3]
# Unique values in 2525_colored_mask.npy: [0 1 2 3]
# Unique values in 1334_colored_mask.npy: [0 1 2 3]
# Unique values in 614_colored_mask.npy: [0 1 3]
# Unique values in 962_colored_mask.npy: [0 1 3]
# Unique values in 2805_colored_mask.npy: [0 1 3]
# Unique values in 3069_colored_mask.npy: [0 1 3]
# Unique values in 1732_colored_mask.npy: [0 1 3]
# Unique values in 78_colored_mask.npy: [0 1 3]
# Unique values in 2669_colored_mask.npy: [0 1 3]
# Unique values in 1966_colored_mask.npy: [0 1]
# Unique values in 2052_colored_mask.npy: [0 1]
# Unique values in 2706_colored_mask.npy: [0 1 3]
# Unique values in 2370_colored_mask.npy: [0 1 3]
# Unique values in 2968_colored_mask.npy: [0 1 3]
# Unique values in 1576_colored_mask.npy: [0 1 2 3]
# Unique values in 2786_colored_mask.npy: [0 1 3]
# Unique values in 2303_colored_mask.npy: [0 1 3]
# Unique values in 2049_colored_mask.npy: [0 1 2 3]
# Unique values in 320_colored_mask.npy: [0 1 3]
# Unique values in 367_colored_mask.npy: [0 1 2]
# Unique values in 1989_colored_mask.npy: [0 1 2 3]
# Unique values in 2750_colored_mask.npy: [0 1 3]
# Unique values in 433_colored_mask.npy: [0 1 3]
# Unique values in 1513_colored_mask.npy: [0 1 2 3]
# Unique values in 1945_colored_mask.npy: [0 1 2 3]
# Unique values in 266_colored_mask.npy: [0 1 3]
# Unique values in 2354_colored_mask.npy: [0 1 3]
# Unique values in 1835_colored_mask.npy: [0 1 3]
# Unique values in 3133_colored_mask.npy: [0 1 2 3]
# Unique values in 899_colored_mask.npy: [0 1 2 3]
# Unique values in 2841_colored_mask.npy: [0 1 2 3]
# Unique values in 245_colored_mask.npy: [0 1 3]
# Unique values in 2679_colored_mask.npy: [0 1 3]
# Unique values in 861_colored_mask.npy: [0 1 3]
# Unique values in 2328_colored_mask.npy: [0 1 3]
# Unique values in 335_colored_mask.npy: [0 1 3]
# Unique values in 1552_colored_mask.npy: [0 1 2 3]
# Unique values in 2856_colored_mask.npy: [0 1 2 3]
# Unique values in 1617_colored_mask.npy: [0 1 2 3]
# Unique values in 1248_colored_mask.npy: [0 1 2 3]
# Unique values in 460_colored_mask.npy: [0 1 2]
# Unique values in 648_colored_mask.npy: [0 1 2 3]
# Unique values in 232_colored_mask.npy: [0 1 2 3]
# Unique values in 1908_colored_mask.npy: [0 1 3]
# Unique values in 883_colored_mask.npy: [0 1 3]
# Unique values in 752_colored_mask.npy: [0 1 3]
# Unique values in 2044_colored_mask.npy: [0 1]
# Unique values in 2410_colored_mask.npy: [0 1 3]
# Unique values in 2739_colored_mask.npy: [0 1 2 3]
# Unique values in 1659_colored_mask.npy: [0 1 2 3]
# Unique values in 3155_colored_mask.npy: [0 1 3]
# Unique values in 1587_colored_mask.npy: [0 1 3]
# Unique values in 1394_colored_mask.npy: [0 1 3]
# Unique values in 3168_colored_mask.npy: [0 1 3]
# Unique values in 49_colored_mask.npy: [0 1 2]
# Unique values in 890_colored_mask.npy: [0 1 3]
# Unique values in 1452_colored_mask.npy: [0 1 3]
# Unique values in 1442_colored_mask.npy: [0 1 2 3]
# Unique values in 969_colored_mask.npy: [0 1 3]
# Unique values in 797_colored_mask.npy: [0 1 3]
# Unique values in 2158_colored_mask.npy: [0 1 3]
# Unique values in 2004_colored_mask.npy: [0 1 2 3]
# Unique values in 203_colored_mask.npy: [0 1 2 3]
# Unique values in 1693_colored_mask.npy: [0 1 3]
# Unique values in 1147_colored_mask.npy: [0 1 3]
# Unique values in 3230_colored_mask.npy: [0 1 3]
# Unique values in 640_colored_mask.npy: [0 1 3]
# Unique values in 1184_colored_mask.npy: [0 1 3]
# Unique values in 3071_colored_mask.npy: [0 1 2 3]
# Unique values in 1390_colored_mask.npy: [0 1 2 3]
# Unique values in 1046_colored_mask.npy: [0 1]
# Unique values in 679_colored_mask.npy: [0 1 2 3]
# Unique values in 1869_colored_mask.npy: [0 1 3]
# Unique values in 2757_colored_mask.npy: [0 1 2]
# Unique values in 714_colored_mask.npy: [0 1 3]
# Unique values in 542_colored_mask.npy: [0 1 3]
# Unique values in 3197_colored_mask.npy: [0 1 2 3]
# Unique values in 1407_colored_mask.npy: [0 1 2 3]
# Unique values in 505_colored_mask.npy: [0 1 2 3]
# Unique values in 1643_colored_mask.npy: [0 1 3]
# Unique values in 2549_colored_mask.npy: [0 1 2 3]
# Unique values in 2994_colored_mask.npy: [0 1 2]
# Unique values in 2192_colored_mask.npy: [0 1 2 3]
# Unique values in 2390_colored_mask.npy: [0 1 3]
# Unique values in 3178_colored_mask.npy: [0 1 3]
# Unique values in 66_colored_mask.npy: [0 1 2 3]
# Unique values in 2220_colored_mask.npy: [0 1 3]
# Unique values in 801_colored_mask.npy: [0 1 3]
# Unique values in 1143_colored_mask.npy: [0 1 2]
# Unique values in 1230_colored_mask.npy: [0 1 3]
# Unique values in 1425_colored_mask.npy: [0 1 3]
# Unique values in 1578_colored_mask.npy: [0 1 2 3]
# Unique values in 1321_colored_mask.npy: [0 1 2 3]
# Unique values in 1747_colored_mask.npy: [0 1 2 3]
# Unique values in 1662_colored_mask.npy: [0 1 2]
# Unique values in 2572_colored_mask.npy: [0 1 3]
# Unique values in 2074_colored_mask.npy: [0 1 3]
# Unique values in 1467_colored_mask.npy: [0 1 3]
# Unique values in 2173_colored_mask.npy: [0 1 3]
# Unique values in 483_colored_mask.npy: [0 1 3]
# Unique values in 306_colored_mask.npy: [0 1 3]
# Unique values in 2179_colored_mask.npy: [0 1 3]
# Unique values in 1681_colored_mask.npy: [0 1 3]
# Unique values in 1504_colored_mask.npy: [0 1 2 3]
# Unique values in 2524_colored_mask.npy: [0 1 3]
# Unique values in 2345_colored_mask.npy: [0 1 2 3]
# Unique values in 2205_colored_mask.npy: [0 1 3]
# Unique values in 647_colored_mask.npy: [0 1 2 3]
# Unique values in 3210_colored_mask.npy: [0 1 3]
# Unique values in 395_colored_mask.npy: [0 1 2 3]
# Unique values in 423_colored_mask.npy: [0 1 2 3]
# Unique values in 2566_colored_mask.npy: [0 1 2 3]
# Unique values in 1612_colored_mask.npy: [0 1 3]
# Unique values in 1689_colored_mask.npy: [0 1 3]
# Unique values in 1204_colored_mask.npy: [0 1 3]
# Unique values in 3056_colored_mask.npy: [0 1 3]
# Unique values in 3042_colored_mask.npy: [0 1 3]
# Unique values in 307_colored_mask.npy: [0 1 2 3]
# Unique values in 1057_colored_mask.npy: [0 1 2 3]
# Unique values in 593_colored_mask.npy: [0 1 3]
# Unique values in 1322_colored_mask.npy: [0 1 3]
# Unique values in 504_colored_mask.npy: [0 1 2 3]
# Unique values in 2299_colored_mask.npy: [0 1 2]
# Unique values in 129_colored_mask.npy: [0 1 2 3]
# Unique values in 875_colored_mask.npy: [0 1 2 3]
# Unique values in 2_colored_mask.npy: [0 1 3]
# Unique values in 205_colored_mask.npy: [0 1 3]
# Unique values in 3237_colored_mask.npy: [0 1 3]
# Unique values in 3154_colored_mask.npy: [0 1 3]
# Unique values in 2586_colored_mask.npy: [0 1 3]
# Unique values in 422_colored_mask.npy: [0 1 2 3]
# Unique values in 2180_colored_mask.npy: [0 1 3]
# Unique values in 2197_colored_mask.npy: [0 1 2 3]
# Unique values in 133_colored_mask.npy: [0 1 2 3]
# Unique values in 2686_colored_mask.npy: [0 1 3]
# Unique values in 1265_colored_mask.npy: [0 1 3]
# Unique values in 551_colored_mask.npy: [0 1 2 3]
# Unique values in 2263_colored_mask.npy: [0 1 3]
# Unique values in 1165_colored_mask.npy: [0 1]
# Unique values in 3126_colored_mask.npy: [0 1 3]
# Unique values in 1379_colored_mask.npy: [0 1 3]
# Unique values in 2682_colored_mask.npy: [0 1 2 3]
# Unique values in 1521_colored_mask.npy: [0 1 2 3]
# Unique values in 3150_colored_mask.npy: [0 1 2]
# Unique values in 2320_colored_mask.npy: [0 1 3]
# Unique values in 1970_colored_mask.npy: [0 1 3]
# Unique values in 1358_colored_mask.npy: [0 1 3]
# Unique values in 134_colored_mask.npy: [0 1 3]
# Unique values in 810_colored_mask.npy: [0 1 3]
# Unique values in 1061_colored_mask.npy: [0 1 2]
# Unique values in 989_colored_mask.npy: [0 1 2 3]
# Unique values in 2313_colored_mask.npy: [0 1 3]
# Unique values in 1323_colored_mask.npy: [0 1 3]
# Unique values in 1906_colored_mask.npy: [0 1 2 3]
# Unique values in 1445_colored_mask.npy: [0 1 3]
# Unique values in 1155_colored_mask.npy: [0 1 3]
# Unique values in 1016_colored_mask.npy: [0 1 3]
# Unique values in 987_colored_mask.npy: [0 1 3]
# Unique values in 2772_colored_mask.npy: [0 1 3]
# Unique values in 249_colored_mask.npy: [0 1 3]
# Unique values in 1883_colored_mask.npy: [0 1 3]
# Unique values in 3174_colored_mask.npy: [0 1 2 3]
# Unique values in 213_colored_mask.npy: [0 1 3]
# Unique values in 2026_colored_mask.npy: [0 1 3]
# Unique values in 2198_colored_mask.npy: [0 1 3]
# Unique values in 1135_colored_mask.npy: [0 1 2 3]
# Unique values in 830_colored_mask.npy: [0 1 3]
# Unique values in 1399_colored_mask.npy: [0 1 2 3]
# Unique values in 3070_colored_mask.npy: [0 1 3]
# Unique values in 2088_colored_mask.npy: [0 1 3]
# Unique values in 431_colored_mask.npy: [0 1 2 3]
# Unique values in 1283_colored_mask.npy: [0 1 2 3]
# Unique values in 2322_colored_mask.npy: [0 1]
# Unique values in 3137_colored_mask.npy: [0 1 2 3]
# Unique values in 1851_colored_mask.npy: [0 1 2]
# Unique values in 597_colored_mask.npy: [0 1 2 3]
# Unique values in 2832_colored_mask.npy: [0 1 2]
# Unique values in 3031_colored_mask.npy: [0 1 2 3]
# Unique values in 461_colored_mask.npy: [0 1 2 3]
# Unique values in 1923_colored_mask.npy: [0 1 3]
# Unique values in 1021_colored_mask.npy: [0 1 3]
# Unique values in 136_colored_mask.npy: [0 1 3]
# Unique values in 1015_colored_mask.npy: [0 1 3]
# Unique values in 1538_colored_mask.npy: [0 1 3]
# Unique values in 1252_colored_mask.npy: [0 1 2 3]
# Unique values in 1861_colored_mask.npy: [0 1 2 3]
# Unique values in 1849_colored_mask.npy: [0 1 2 3]
# Unique values in 2212_colored_mask.npy: [0 1 2]
# Unique values in 2461_colored_mask.npy: [0 1 3]
# Unique values in 1236_colored_mask.npy: [0 1 3]
# Unique values in 1141_colored_mask.npy: [0 1 3]
# Unique values in 2861_colored_mask.npy: [0 1 2 3]
# Unique values in 2769_colored_mask.npy: [0 1 3]
# Unique values in 2710_colored_mask.npy: [0 1 3]
# Unique values in 2092_colored_mask.npy: [0 1 2]
# Unique values in 925_colored_mask.npy: [0 1 3]
# Unique values in 2969_colored_mask.npy: [0 1 2 3]
# Unique values in 1903_colored_mask.npy: [0 1 3]
# Unique values in 2689_colored_mask.npy: [0 1 2 3]
# Unique values in 454_colored_mask.npy: [0 1 2 3]
# Unique values in 2607_colored_mask.npy: [0 1 3]
# Unique values in 605_colored_mask.npy: [0 1 3]
# Unique values in 754_colored_mask.npy: [0 1 3]
# Unique values in 2691_colored_mask.npy: [0 1 2 3]
# Unique values in 90_colored_mask.npy: [0 1 2]
# Unique values in 25_colored_mask.npy: [0 1 2 3]
# Unique values in 3120_colored_mask.npy: [0 1 2]
# Unique values in 2867_colored_mask.npy: [0 1 2]
# Unique values in 1801_colored_mask.npy: [0 1]
# Unique values in 3000_colored_mask.npy: [0 1 3]
# Unique values in 3059_colored_mask.npy: [0 1 3]
# Unique values in 2085_colored_mask.npy: [0 1 3]
# Unique values in 147_colored_mask.npy: [0 1 2]
# Unique values in 728_colored_mask.npy: [0 1 3]
# Unique values in 1656_colored_mask.npy: [0 1 3]
# Unique values in 2599_colored_mask.npy: [0 1 2 3]

# %%
# CELL 4

# Split data into training, validation, and test sets
X_temp, X_test, Y_temp, Y_test = train_test_split(
    images, masks, test_size=0.1, random_state=42
)
X_train, X_val, Y_train, Y_val = train_test_split(
    X_temp, Y_temp, test_size=0.2, random_state=42
)

# Print dataset shapes
print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)
print("X_val shape:", X_val.shape)
print("Y_val shape:", Y_val.shape)
print("X_test shape:", X_test.shape)
print("Y_test shape:", Y_test.shape)
# Out:
# X_train shape: (1839, 512, 128, 3)
# Y_train shape: (1839, 512, 128, 4)
# X_val shape: (460, 512, 128, 3)
# Y_val shape: (460, 512, 128, 4)
# X_test shape: (256, 512, 128, 3)
# Y_test shape: (256, 512, 128, 4)

# %%
# CELL 5
# WORKING CODE

from sklearn.utils import class_weight

# Flatten masks to compute class weights
all_masks_flat = np.argmax(Y_train, axis=-1).flatten()
unique_classes, counts = np.unique(all_masks_flat, return_counts=True)
class_distribution = dict(zip(unique_classes, counts))
print("Class distribution in training masks:", class_distribution)

# Manually adjust class weights to emphasize minority classes
class_weights = np.array([0.5, 1.0, 5.0, 5.0])  # Emphasize classes 2 and 3
class_weights_dict = {i: class_weights[i] for i in range(len(class_weights))}
print("Adjusted Class Weights:", class_weights_dict)


# THIS IS CHANGEABLE
# EXPERIMENTAL CODE
# CELL 5
# Out:
# Class distribution in training masks: {0: 105257004, 1: 15036849, 2: 92859, 3: 133992}
# Adjusted Class Weights: {0: 0.5, 1: 1.0, 2: 5.0, 3: 5.0}

# %%
# CELL 6

import tensorflow.keras.backend as K
import tensorflow as tf

def focal_loss(gamma=2., alpha=class_weights):
    alpha = K.constant(alpha, dtype=tf.float32)
    gamma = float(gamma)

    def focal_loss_fixed(y_true, y_pred):
        y_pred = K.clip(y_pred, K.epsilon(), 1. - K.epsilon())
        cross_entropy = -y_true * K.log(y_pred)
        weight = alpha * K.pow(1 - y_pred, gamma)
        loss = weight * cross_entropy
        return K.sum(loss, axis=-1)

    return focal_loss_fixed

def dice_loss(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    smooth = 1e-6
    return 1 - (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def combined_loss(y_true, y_pred):
    return focal_loss()(y_true, y_pred) + dice_loss(y_true, y_pred)

loss_function = combined_loss

# THIS IS CHANGEABLE
# EXPERIMENTAL CODE

# %%
# CELL 7
# WORKING CODE

from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate, UpSampling2D, BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

def unetplusplus(input_size=(img_height, img_width, channels), num_classes=num_classes):
    inputs = Input(input_size)
    
    # Encoder
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(1e-4))(inputs)
    c1 = BatchNormalization()(c1)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(1e-4))(c1)
    c1 = BatchNormalization()(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(1e-4))(p1)
    c2 = BatchNormalization()(c2)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(1e-4))(c2)
    c2 = BatchNormalization()(c2)
    p2 = MaxPooling2D((2, 2))(c2)
    
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(1e-4))(p2)
    c3 = BatchNormalization()(c3)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(1e-4))(c3)
    c3 = BatchNormalization()(c3)
    p3 = MaxPooling2D((2, 2))(c3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(1e-4))(p3)
    c4 = BatchNormalization()(c4)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(1e-4))(c4)
    c4 = BatchNormalization()(c4)
    p4 = MaxPooling2D((2, 2))(c4)
    
    # Bottleneck
    c5 = Conv2D(1024, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(1e-4))(p4)
    c5 = BatchNormalization()(c5)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(1024, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(1e-4))(c5)
    c5 = BatchNormalization()(c5)
    
    # Decoder with Deep Supervision
    u6 = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(512, (3, 3), activation='relu', padding='same')(u6)
    c6 = BatchNormalization()(c6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(512, (3, 3), activation='relu', padding='same')(c6)
    c6 = BatchNormalization()(c6)
    d6 = Conv2D(num_classes, (1, 1), activation='softmax')(c6)  # Deep Supervision Output 1
    d6_up = UpSampling2D(size=(8, 8), interpolation='bilinear', name='output_d6')(d6)  # Upsample to input size

    u7 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(256, (3, 3), activation='relu', padding='same')(u7)
    c7 = BatchNormalization()(c7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(256, (3, 3), activation='relu', padding='same')(c7)
    c7 = BatchNormalization()(c7)
    d7 = Conv2D(num_classes, (1, 1), activation='softmax')(c7)  # Deep Supervision Output 2
    d7_up = UpSampling2D(size=(4, 4), interpolation='bilinear', name='output_d7')(d7)  # Upsample to input size

    u8 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(128, (3, 3), activation='relu', padding='same')(u8)
    c8 = BatchNormalization()(c8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv2D(128, (3, 3), activation='relu', padding='same')(c8)
    c8 = BatchNormalization()(c8)
    d8 = Conv2D(num_classes, (1, 1), activation='softmax')(c8)  # Deep Supervision Output 3
    d8_up = UpSampling2D(size=(2, 2), interpolation='bilinear', name='output_d8')(d8)  # Upsample to input size

    u9 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv2D(64, (3, 3), activation='relu', padding='same')(u9)
    c9 = BatchNormalization()(c9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv2D(64, (3, 3), activation='relu', padding='same')(c9)
    c9 = BatchNormalization()(c9)
    d9 = Conv2D(num_classes, (1, 1), activation='softmax', name='output_d9')(c9)  # Deep Supervision Output 4

    # Final Output
    outputs = Conv2D(num_classes, (1, 1), activation='softmax', name='final_output')(c9)

    model = Model(inputs=[inputs], outputs=[outputs, d6_up, d7_up, d8_up, d9])
    return model

# Build the model
model = unetplusplus()
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 512, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 512, 128,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 512, 128,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 512, 128,  │     36,928 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 128,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 256, 64,   │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 256, 64,   │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 64,   │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256, 64,   │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 256, 64,   │    147,584 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 64,   │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 128, 32,   │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 32,   │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 32,   │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128, 32,   │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 128, 32,   │    590,080 │ dropout_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 32,   │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 64, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 16,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 16,    │      2,048 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 64, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 16,    │  2,359,808 │ dropout_3[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 16,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 32, 8,     │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 8,     │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 8,     │      4,096 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32, 8,     │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 32, 8,     │  9,438,208 │ dropout_4[0][0]   │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 8,     │      4,096 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 64, 16,    │  2,097,664 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 64, 16,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 16,    │      2,048 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 64, 16,    │  2,359,808 │ dropout_5[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 16,    │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 128, 32,   │    524,544 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 32,   │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 128, 32,   │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 32,   │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128, 32,   │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 32,   │    590,080 │ dropout_6[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 32,   │      1,024 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 256, 64,   │    131,200 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 256, 64,   │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 64,   │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 64,   │        512 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256, 64,   │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 64,   │    147,584 │ dropout_7[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 64,   │        512 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 512, 128,  │     32,832 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 512, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 512, 128,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 128,  │        256 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 512, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 512, 128,  │     36,928 │ dropout_8[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 128,  │        256 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 16, 4) │      2,052 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 32,   │      1,028 │ batch_normalizat… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 64,   │        516 │ batch_normalizat… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_output        │ (None, 512, 128,  │        260 │ batch_normalizat… │
# │ (Conv2D)            │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_d6           │ (None, 512, 128,  │          0 │ conv2d_12[0][0]   │
# │ (UpSampling2D)      │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_d7           │ (None, 512, 128,  │          0 │ conv2d_15[0][0]   │
# │ (UpSampling2D)      │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_d8           │ (None, 512, 128,  │          0 │ conv2d_18[0][0]   │
# │ (UpSampling2D)      │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_d9 (Conv2D)  │ (None, 512, 128,  │        260 │ batch_normalizat… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,059,348 (118.48 MB)
#  Trainable params: 31,047,572 (118.44 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %%
# CELL 8

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

optimizer = Adam(learning_rate=1e-4)  # Starting with a low learning rate

# Implement IoU metric
def iou_metric(y_true, y_pred):
    y_pred = K.argmax(y_pred, axis=-1)
    y_true = K.argmax(y_true, axis=-1)
    intersection = K.sum(K.cast(y_true * y_pred, 'float32'))
    union = K.sum(K.cast(y_true + y_pred, 'float32')) - intersection
    return intersection / (union + K.epsilon())

# Compile the model
model.compile(
    optimizer=optimizer,
    loss={
        'final_output': loss_function,
        'output_d6': loss_function,
        'output_d7': loss_function,
        'output_d8': loss_function,
        'output_d9': loss_function
    },
    loss_weights={
        'final_output': 1.0,
        'output_d6': 0.8,
        'output_d7': 0.6,
        'output_d8': 0.4,
        'output_d9': 0.2
    },
    metrics={
        'final_output': ['accuracy', iou_metric],
        'output_d6': 'accuracy',
        'output_d7': 'accuracy',
        'output_d8': 'accuracy',
        'output_d9': 'accuracy'
    }
)

# Learning Rate Scheduler Callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_final_output_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1,
    mode='min'
)

# Optional: Print the model summary
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 512, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 512, 128,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 512, 128,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 512, 128,  │     36,928 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 128,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 256, 64,   │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 256, 64,   │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 64,   │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256, 64,   │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 256, 64,   │    147,584 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 64,   │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 128, 32,   │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 32,   │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 32,   │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128, 32,   │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 128, 32,   │    590,080 │ dropout_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 32,   │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 64, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 16,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 16,    │      2,048 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 64, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 16,    │  2,359,808 │ dropout_3[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 16,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 32, 8,     │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 8,     │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 8,     │      4,096 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32, 8,     │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 32, 8,     │  9,438,208 │ dropout_4[0][0]   │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 8,     │      4,096 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 64, 16,    │  2,097,664 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 64, 16,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 16,    │      2,048 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 64, 16,    │  2,359,808 │ dropout_5[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 16,    │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 128, 32,   │    524,544 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 32,   │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 128, 32,   │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 32,   │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128, 32,   │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 32,   │    590,080 │ dropout_6[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 32,   │      1,024 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 256, 64,   │    131,200 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 256, 64,   │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 64,   │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 64,   │        512 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256, 64,   │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 64,   │    147,584 │ dropout_7[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 64,   │        512 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 512, 128,  │     32,832 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 512, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 512, 128,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 128,  │        256 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 512, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 512, 128,  │     36,928 │ dropout_8[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 128,  │        256 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 16, 4) │      2,052 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 32,   │      1,028 │ batch_normalizat… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 64,   │        516 │ batch_normalizat… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_output        │ (None, 512, 128,  │        260 │ batch_normalizat… │
# │ (Conv2D)            │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_d6           │ (None, 512, 128,  │          0 │ conv2d_12[0][0]   │
# │ (UpSampling2D)      │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_d7           │ (None, 512, 128,  │          0 │ conv2d_15[0][0]   │
# │ (UpSampling2D)      │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_d8           │ (None, 512, 128,  │          0 │ conv2d_18[0][0]   │
# │ (UpSampling2D)      │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_d9 (Conv2D)  │ (None, 512, 128,  │        260 │ batch_normalizat… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,059,348 (118.48 MB)
#  Trainable params: 31,047,572 (118.44 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %%
# CELL 9
from tensorflow.keras.callbacks import ModelCheckpoint
import os

# Ensure that checkpoint_dir is defined
checkpoint_dir = r"/kaggle/working/"
os.makedirs(checkpoint_dir, exist_ok=True)

# Setup model checkpoint callback
checkpoint_callback = ModelCheckpoint(
    filepath=os.path.join(checkpoint_dir, "unetplusplus_best.weights.h5"),
    save_weights_only=True,
    save_best_only=True,  # Save weights when the model improves
    monitor='val_loss',  # Monitor the validation loss (you can adjust if needed)
    mode='min',  # Save when the loss decreases (minimizing loss)
    verbose=1
)

# %%
# CELL 10
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

early_stopping = EarlyStopping(
    monitor='val_final_output_loss',
    patience=10,  # Increased patience due to data augmentation
    mode='min',
    restore_best_weights=True
)

# Prepare the targets for each output
Y_train_targets = {
    'final_output': Y_train,
    'output_d6': Y_train,
    'output_d7': Y_train,
    'output_d8': Y_train,
    'output_d9': Y_train
}

Y_val_targets = {
    'final_output': Y_val,
    'output_d6': Y_val,
    'output_d7': Y_val,
    'output_d8': Y_val,
    'output_d9': Y_val
}

# Data Augmentation
data_gen_args = dict(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

image_datagen = ImageDataGenerator(**data_gen_args)
mask_datagen = ImageDataGenerator(**data_gen_args)

# Provide the same seed and keyword arguments to the flow methods
seed = 42
image_datagen.fit(X_train, augment=True, seed=seed)
mask_datagen.fit(Y_train, augment=True, seed=seed)

# Create generators
image_generator = image_datagen.flow(X_train, batch_size=batch_size, seed=seed)
mask_generator = mask_datagen.flow(Y_train, batch_size=batch_size, seed=seed)

# Create custom generator function
def create_generator(image_gen, mask_gen):
    while True:
        X = next(image_gen)
        Y = next(mask_gen)
        Y_targets = {
            'final_output': Y,
            'output_d6': Y,
            'output_d7': Y,
            'output_d8': Y,
            'output_d9': Y
        }
        yield X, Y_targets

# Create train and validation generators
train_generator = create_generator(image_generator, mask_generator)

# Validation data generator (without augmentation)
val_image_datagen = ImageDataGenerator()
val_mask_datagen = ImageDataGenerator()

val_image_generator = val_image_datagen.flow(X_val, batch_size=batch_size, seed=seed, shuffle=False)
val_mask_generator = val_mask_datagen.flow(Y_val, batch_size=batch_size, seed=seed, shuffle=False)

val_generator = create_generator(val_image_generator, val_mask_generator)

# Adjust steps per epoch
steps_per_epoch = len(X_train) // batch_size
validation_steps = len(X_val) // batch_size

try:
    history = model.fit(
        train_generator,
        steps_per_epoch=steps_per_epoch,
        validation_data=val_generator,
        validation_steps=validation_steps,
        epochs=epochs,
        callbacks=[checkpoint_callback, early_stopping, reduce_lr],
        verbose=1
    )
    # Save the model after successful training
    model.save(os.path.join(checkpoint_dir, "unetplusplus_final.h5"))
    print("Training completed. Model saved to disk.")
except KeyboardInterrupt:
    print("Training interrupted. Saving model.")
    model.save(os.path.join(checkpoint_dir, "unetplusplus_interrupted.h5"))
    print("Model saved.")
# Out:
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733116700.157976     217 service.cc:145] XLA service 0x79ad20001eb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733116700.158045     217 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1733116700.158050     217 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1733116746.145306     217 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - final_output_accuracy: 0.8448 - final_output_iou_metric: 0.5417 - loss: 1.7202 - output_d6_accuracy: 0.8970 - output_d7_accuracy: 0.8954 - output_d8_accuracy: 0.8643 - output_d9_accuracy: 0.7210
# Epoch 1: val_loss improved from inf to 1.08857, saving model to /kaggle/working/unetplusplus_best.weights.h5
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 198s 303ms/step - final_output_accuracy: 0.8450 - final_output_iou_metric: 0.5419 - loss: 1.7192 - output_d6_accuracy: 0.8970 - output_d7_accuracy: 0.8955 - output_d8_accuracy: 0.8644 - output_d9_accuracy: 0.7213 - val_final_output_accuracy: 0.9270 - val_final_output_iou_metric: 0.5268 - val_loss: 1.0886 - val_output_d6_accuracy: 0.8917 - val_output_d7_accuracy: 0.8934 - val_output_d8_accuracy: 0.8967 - val_output_d9_accuracy: 0.9290 - learning_rate: 1.0000e-04
# Epoch 2/20
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_final_output_loss` which is not available. Available metrics are: final_output_accuracy,final_output_iou_metric,loss,output_d6_accuracy,output_d7_accuracy,output_d8_accuracy,output_d9_accuracy,val_final_output_accuracy,val_final_output_iou_metric,val_loss,val_output_d6_accuracy,val_output_d7_accuracy,val_output_d8_accuracy,val_output_d9_accuracy
#   current = self.get_monitor_value(logs)
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py:96: UserWarning: Learning rate reduction is conditioned on metric `val_final_output_loss` which is not available. Available metrics are: final_output_accuracy,final_output_iou_metric,loss,output_d6_accuracy,output_d7_accuracy,output_d8_accuracy,output_d9_accuracy,val_final_output_accuracy,val_final_output_iou_metric,val_loss,val_output_d6_accuracy,val_output_d7_accuracy,val_output_d8_accuracy,val_output_d9_accuracy,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - final_output_accuracy: 0.9511 - final_output_iou_metric: 0.7249 - loss: 0.8560 - output_d6_accuracy: 0.9330 - output_d7_accuracy: 0.9362 - output_d8_accuracy: 0.9309 - output_d9_accuracy: 0.9458
# Epoch 2: val_loss improved from 1.08857 to 0.75909, saving model to /kaggle/working/unetplusplus_best.weights.h5
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 182s 304ms/step - final_output_accuracy: 0.9512 - final_output_iou_metric: 0.7249 - loss: 0.8558 - output_d6_accuracy: 0.9330 - output_d7_accuracy: 0.9362 - output_d8_accuracy: 0.9309 - output_d9_accuracy: 0.9458 - val_final_output_accuracy: 0.9466 - val_final_output_iou_metric: 0.7503 - val_loss: 0.7591 - val_output_d6_accuracy: 0.9130 - val_output_d7_accuracy: 0.9184 - val_output_d8_accuracy: 0.9084 - val_output_d9_accuracy: 0.9406 - learning_rate: 1.0000e-04
# Epoch 3/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - final_output_accuracy: 0.9540 - final_output_iou_metric: 0.7493 - loss: 0.6710 - output_d6_accuracy: 0.9370 - output_d7_accuracy: 0.9415 - output_d8_accuracy: 0.9383 - output_d9_accuracy: 0.9518
# Epoch 3: val_loss improved from 0.75909 to 0.67268, saving model to /kaggle/working/unetplusplus_best.weights.h5
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 139s 302ms/step - final_output_accuracy: 0.9540 - final_output_iou_metric: 0.7493 - loss: 0.6710 - output_d6_accuracy: 0.9370 - output_d7_accuracy: 0.9415 - output_d8_accuracy: 0.9383 - output_d9_accuracy: 0.9518 - val_final_output_accuracy: 0.9452 - val_final_output_iou_metric: 0.7526 - val_loss: 0.6727 - val_output_d6_accuracy: 0.9231 - val_output_d7_accuracy: 0.9249 - val_output_d8_accuracy: 0.8983 - val_output_d9_accuracy: 0.9419 - learning_rate: 1.0000e-04
# Epoch 4/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - final_output_accuracy: 0.9567 - final_output_iou_metric: 0.7680 - loss: 0.5630 - output_d6_accuracy: 0.9401 - output_d7_accuracy: 0.9451 - output_d8_accuracy: 0.9429 - output_d9_accuracy: 0.9548
# Epoch 4: val_loss improved from 0.67268 to 0.60408, saving model to /kaggle/working/unetplusplus_best.weights.h5
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 139s 302ms/step - final_output_accuracy: 0.9566 - final_output_iou_metric: 0.7680 - loss: 0.5629 - output_d6_accuracy: 0.9401 - output_d7_accuracy: 0.9451 - output_d8_accuracy: 0.9429 - output_d9_accuracy: 0.9548 - val_final_output_accuracy: 0.9441 - val_final_output_iou_metric: 0.7480 - val_loss: 0.6041 - val_output_d6_accuracy: 0.9194 - val_output_d7_accuracy: 0.9243 - val_output_d8_accuracy: 0.9180 - val_output_d9_accuracy: 0.9409 - learning_rate: 1.0000e-04
# Epoch 5/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - final_output_accuracy: 0.9569 - final_output_iou_metric: 0.7742 - loss: 0.5143 - output_d6_accuracy: 0.9408 - output_d7_accuracy: 0.9465 - output_d8_accuracy: 0.9451 - output_d9_accuracy: 0.9555
# Epoch 5: val_loss did not improve from 0.60408
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 137s 299ms/step - final_output_accuracy: 0.9570 - final_output_iou_metric: 0.7742 - loss: 0.5143 - output_d6_accuracy: 0.9408 - output_d7_accuracy: 0.9465 - output_d8_accuracy: 0.9451 - output_d9_accuracy: 0.9556 - val_final_output_accuracy: 0.9296 - val_final_output_iou_metric: 0.7023 - val_loss: 0.6101 - val_output_d6_accuracy: 0.9104 - val_output_d7_accuracy: 0.9189 - val_output_d8_accuracy: 0.9115 - val_output_d9_accuracy: 0.9281 - learning_rate: 1.0000e-04
# Epoch 6/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - final_output_accuracy: 0.9571 - final_output_iou_metric: 0.7747 - loss: 0.4783 - output_d6_accuracy: 0.9412 - output_d7_accuracy: 0.9473 - output_d8_accuracy: 0.9467 - output_d9_accuracy: 0.9564
# Epoch 6: val_loss improved from 0.60408 to 0.50322, saving model to /kaggle/working/unetplusplus_best.weights.h5
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 138s 301ms/step - final_output_accuracy: 0.9571 - final_output_iou_metric: 0.7747 - loss: 0.4783 - output_d6_accuracy: 0.9412 - output_d7_accuracy: 0.9473 - output_d8_accuracy: 0.9467 - output_d9_accuracy: 0.9564 - val_final_output_accuracy: 0.9497 - val_final_output_iou_metric: 0.7585 - val_loss: 0.5032 - val_output_d6_accuracy: 0.9310 - val_output_d7_accuracy: 0.9373 - val_output_d8_accuracy: 0.9359 - val_output_d9_accuracy: 0.9492 - learning_rate: 1.0000e-04
# Epoch 7/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - final_output_accuracy: 0.9583 - final_output_iou_metric: 0.7834 - loss: 0.4475 - output_d6_accuracy: 0.9429 - output_d7_accuracy: 0.9493 - output_d8_accuracy: 0.9492 - output_d9_accuracy: 0.9580
# Epoch 7: val_loss did not improve from 0.50322
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 137s 299ms/step - final_output_accuracy: 0.9583 - final_output_iou_metric: 0.7834 - loss: 0.4475 - output_d6_accuracy: 0.9429 - output_d7_accuracy: 0.9493 - output_d8_accuracy: 0.9492 - output_d9_accuracy: 0.9580 - val_final_output_accuracy: 0.9469 - val_final_output_iou_metric: 0.7073 - val_loss: 0.5434 - val_output_d6_accuracy: 0.9219 - val_output_d7_accuracy: 0.9318 - val_output_d8_accuracy: 0.9289 - val_output_d9_accuracy: 0.9471 - learning_rate: 1.0000e-04
# Epoch 8/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - final_output_accuracy: 0.9593 - final_output_iou_metric: 0.7848 - loss: 0.4282 - output_d6_accuracy: 0.9439 - output_d7_accuracy: 0.9506 - output_d8_accuracy: 0.9512 - output_d9_accuracy: 0.9591
# Epoch 8: val_loss did not improve from 0.50322
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 137s 298ms/step - final_output_accuracy: 0.9593 - final_output_iou_metric: 0.7848 - loss: 0.4282 - output_d6_accuracy: 0.9439 - output_d7_accuracy: 0.9506 - output_d8_accuracy: 0.9512 - output_d9_accuracy: 0.9591 - val_final_output_accuracy: 0.9256 - val_final_output_iou_metric: 0.6796 - val_loss: 0.5770 - val_output_d6_accuracy: 0.8987 - val_output_d7_accuracy: 0.9146 - val_output_d8_accuracy: 0.9225 - val_output_d9_accuracy: 0.9292 - learning_rate: 1.0000e-04
# Epoch 9/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - final_output_accuracy: 0.9595 - final_output_iou_metric: 0.7873 - loss: 0.4114 - output_d6_accuracy: 0.9440 - output_d7_accuracy: 0.9513 - output_d8_accuracy: 0.9527 - output_d9_accuracy: 0.9595
# Epoch 9: val_loss did not improve from 0.50322
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 137s 298ms/step - final_output_accuracy: 0.9595 - final_output_iou_metric: 0.7873 - loss: 0.4114 - output_d6_accuracy: 0.9440 - output_d7_accuracy: 0.9513 - output_d8_accuracy: 0.9527 - output_d9_accuracy: 0.9595 - val_final_output_accuracy: 0.9195 - val_final_output_iou_metric: 0.6680 - val_loss: 0.5838 - val_output_d6_accuracy: 0.9118 - val_output_d7_accuracy: 0.9263 - val_output_d8_accuracy: 0.9247 - val_output_d9_accuracy: 0.9240 - learning_rate: 1.0000e-04
# Epoch 10/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - final_output_accuracy: 0.9593 - final_output_iou_metric: 0.7883 - loss: 0.4037 - output_d6_accuracy: 0.9444 - output_d7_accuracy: 0.9516 - output_d8_accuracy: 0.9534 - output_d9_accuracy: 0.9594
# Epoch 10: val_loss did not improve from 0.50322
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 137s 298ms/step - final_output_accuracy: 0.9593 - final_output_iou_metric: 0.7883 - loss: 0.4037 - output_d6_accuracy: 0.9444 - output_d7_accuracy: 0.9516 - output_d8_accuracy: 0.9534 - output_d9_accuracy: 0.9594 - val_final_output_accuracy: 0.9403 - val_final_output_iou_metric: 0.7265 - val_loss: 0.5146 - val_output_d6_accuracy: 0.9193 - val_output_d7_accuracy: 0.9288 - val_output_d8_accuracy: 0.9359 - val_output_d9_accuracy: 0.9417 - learning_rate: 1.0000e-04
# Epoch 11/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - final_output_accuracy: 0.9599 - final_output_iou_metric: 0.7936 - loss: 0.3918 - output_d6_accuracy: 0.9450 - output_d7_accuracy: 0.9524 - output_d8_accuracy: 0.9547 - output_d9_accuracy: 0.9600
# Epoch 11: val_loss improved from 0.50322 to 0.47881, saving model to /kaggle/working/unetplusplus_best.weights.h5
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 138s 300ms/step - final_output_accuracy: 0.9599 - final_output_iou_metric: 0.7936 - loss: 0.3918 - output_d6_accuracy: 0.9450 - output_d7_accuracy: 0.9524 - output_d8_accuracy: 0.9547 - output_d9_accuracy: 0.9600 - val_final_output_accuracy: 0.9448 - val_final_output_iou_metric: 0.7546 - val_loss: 0.4788 - val_output_d6_accuracy: 0.9279 - val_output_d7_accuracy: 0.9381 - val_output_d8_accuracy: 0.9414 - val_output_d9_accuracy: 0.9456 - learning_rate: 1.0000e-04
# Epoch 12/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - final_output_accuracy: 0.9594 - final_output_iou_metric: 0.7996 - loss: 0.3899 - output_d6_accuracy: 0.9446 - output_d7_accuracy: 0.9524 - output_d8_accuracy: 0.9547 - output_d9_accuracy: 0.9596
# Epoch 12: val_loss did not improve from 0.47881
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 137s 298ms/step - final_output_accuracy: 0.9594 - final_output_iou_metric: 0.7996 - loss: 0.3899 - output_d6_accuracy: 0.9446 - output_d7_accuracy: 0.9524 - output_d8_accuracy: 0.9547 - output_d9_accuracy: 0.9596 - val_final_output_accuracy: 0.9282 - val_final_output_iou_metric: 0.7070 - val_loss: 0.5361 - val_output_d6_accuracy: 0.9156 - val_output_d7_accuracy: 0.9177 - val_output_d8_accuracy: 0.9274 - val_output_d9_accuracy: 0.9317 - learning_rate: 1.0000e-04
# Epoch 13/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - final_output_accuracy: 0.9608 - final_output_iou_metric: 0.8007 - loss: 0.3749 - output_d6_accuracy: 0.9463 - output_d7_accuracy: 0.9539 - output_d8_accuracy: 0.9567 - output_d9_accuracy: 0.9610
# Epoch 13: val_loss did not improve from 0.47881
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 137s 298ms/step - final_output_accuracy: 0.9608 - final_output_iou_metric: 0.8007 - loss: 0.3749 - output_d6_accuracy: 0.9463 - output_d7_accuracy: 0.9539 - output_d8_accuracy: 0.9567 - output_d9_accuracy: 0.9610 - val_final_output_accuracy: 0.9303 - val_final_output_iou_metric: 0.6992 - val_loss: 0.7424 - val_output_d6_accuracy: 0.7013 - val_output_d7_accuracy: 0.9162 - val_output_d8_accuracy: 0.9238 - val_output_d9_accuracy: 0.9323 - learning_rate: 1.0000e-04
# Epoch 14/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - final_output_accuracy: 0.9607 - final_output_iou_metric: 0.7932 - loss: 0.3708 - output_d6_accuracy: 0.9463 - output_d7_accuracy: 0.9539 - output_d8_accuracy: 0.9568 - output_d9_accuracy: 0.9609
# Epoch 14: val_loss did not improve from 0.47881
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 136s 297ms/step - final_output_accuracy: 0.9607 - final_output_iou_metric: 0.7932 - loss: 0.3708 - output_d6_accuracy: 0.9463 - output_d7_accuracy: 0.9539 - output_d8_accuracy: 0.9568 - output_d9_accuracy: 0.9609 - val_final_output_accuracy: 0.9228 - val_final_output_iou_metric: 0.6817 - val_loss: 0.5268 - val_output_d6_accuracy: 0.9187 - val_output_d7_accuracy: 0.9270 - val_output_d8_accuracy: 0.9321 - val_output_d9_accuracy: 0.9271 - learning_rate: 1.0000e-04
# Epoch 15/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - final_output_accuracy: 0.9614 - final_output_iou_metric: 0.8123 - loss: 0.3635 - output_d6_accuracy: 0.9469 - output_d7_accuracy: 0.9546 - output_d8_accuracy: 0.9578 - output_d9_accuracy: 0.9616
# Epoch 15: val_loss did not improve from 0.47881
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 136s 297ms/step - final_output_accuracy: 0.9614 - final_output_iou_metric: 0.8123 - loss: 0.3635 - output_d6_accuracy: 0.9469 - output_d7_accuracy: 0.9546 - output_d8_accuracy: 0.9578 - output_d9_accuracy: 0.9616 - val_final_output_accuracy: 0.9318 - val_final_output_iou_metric: 0.7110 - val_loss: 0.4926 - val_output_d6_accuracy: 0.9283 - val_output_d7_accuracy: 0.9340 - val_output_d8_accuracy: 0.9362 - val_output_d9_accuracy: 0.9329 - learning_rate: 1.0000e-04
# Epoch 16/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - final_output_accuracy: 0.9607 - final_output_iou_metric: 0.8020 - loss: 0.3632 - output_d6_accuracy: 0.9466 - output_d7_accuracy: 0.9541 - output_d8_accuracy: 0.9574 - output_d9_accuracy: 0.9607
# Epoch 16: val_loss did not improve from 0.47881
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 136s 297ms/step - final_output_accuracy: 0.9607 - final_output_iou_metric: 0.8020 - loss: 0.3632 - output_d6_accuracy: 0.9466 - output_d7_accuracy: 0.9541 - output_d8_accuracy: 0.9574 - output_d9_accuracy: 0.9607 - val_final_output_accuracy: 0.9242 - val_final_output_iou_metric: 0.6700 - val_loss: 0.5498 - val_output_d6_accuracy: 0.9143 - val_output_d7_accuracy: 0.9185 - val_output_d8_accuracy: 0.9283 - val_output_d9_accuracy: 0.9257 - learning_rate: 1.0000e-04
# Epoch 17/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - final_output_accuracy: 0.9619 - final_output_iou_metric: 0.8017 - loss: 0.3545 - output_d6_accuracy: 0.9477 - output_d7_accuracy: 0.9554 - output_d8_accuracy: 0.9588 - output_d9_accuracy: 0.9619
# Epoch 17: val_loss did not improve from 0.47881
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 137s 298ms/step - final_output_accuracy: 0.9619 - final_output_iou_metric: 0.8017 - loss: 0.3545 - output_d6_accuracy: 0.9477 - output_d7_accuracy: 0.9554 - output_d8_accuracy: 0.9588 - output_d9_accuracy: 0.9619 - val_final_output_accuracy: 0.9286 - val_final_output_iou_metric: 0.6901 - val_loss: 0.5284 - val_output_d6_accuracy: 0.9157 - val_output_d7_accuracy: 0.9275 - val_output_d8_accuracy: 0.9330 - val_output_d9_accuracy: 0.9317 - learning_rate: 1.0000e-04
# Epoch 18/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - final_output_accuracy: 0.9608 - final_output_iou_metric: 0.8067 - loss: 0.3575 - output_d6_accuracy: 0.9465 - output_d7_accuracy: 0.9541 - output_d8_accuracy: 0.9574 - output_d9_accuracy: 0.9608
# Epoch 18: val_loss did not improve from 0.47881
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 137s 298ms/step - final_output_accuracy: 0.9608 - final_output_iou_metric: 0.8067 - loss: 0.3575 - output_d6_accuracy: 0.9465 - output_d7_accuracy: 0.9541 - output_d8_accuracy: 0.9574 - output_d9_accuracy: 0.9608 - val_final_output_accuracy: 0.9320 - val_final_output_iou_metric: 0.7143 - val_loss: 0.5198 - val_output_d6_accuracy: 0.9079 - val_output_d7_accuracy: 0.9212 - val_output_d8_accuracy: 0.9317 - val_output_d9_accuracy: 0.9327 - learning_rate: 1.0000e-04
# Epoch 19/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - final_output_accuracy: 0.9610 - final_output_iou_metric: 0.8048 - loss: 0.3567 - output_d6_accuracy: 0.9466 - output_d7_accuracy: 0.9543 - output_d8_accuracy: 0.9579 - output_d9_accuracy: 0.9610
# Epoch 19: val_loss did not improve from 0.47881
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 136s 296ms/step - final_output_accuracy: 0.9610 - final_output_iou_metric: 0.8048 - loss: 0.3567 - output_d6_accuracy: 0.9466 - output_d7_accuracy: 0.9543 - output_d8_accuracy: 0.9579 - output_d9_accuracy: 0.9610 - val_final_output_accuracy: 0.9231 - val_final_output_iou_metric: 0.6883 - val_loss: 0.5029 - val_output_d6_accuracy: 0.9222 - val_output_d7_accuracy: 0.9207 - val_output_d8_accuracy: 0.9299 - val_output_d9_accuracy: 0.9267 - learning_rate: 1.0000e-04
# Epoch 20/20
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - final_output_accuracy: 0.9610 - final_output_iou_metric: 0.8062 - loss: 0.3531 - output_d6_accuracy: 0.9466 - output_d7_accuracy: 0.9544 - output_d8_accuracy: 0.9580 - output_d9_accuracy: 0.9610
# Epoch 20: val_loss improved from 0.47881 to 0.46553, saving model to /kaggle/working/unetplusplus_best.weights.h5
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 137s 299ms/step - final_output_accuracy: 0.9610 - final_output_iou_metric: 0.8062 - loss: 0.3531 - output_d6_accuracy: 0.9466 - output_d7_accuracy: 0.9544 - output_d8_accuracy: 0.9580 - output_d9_accuracy: 0.9610 - val_final_output_accuracy: 0.9424 - val_final_output_iou_metric: 0.7429 - val_loss: 0.4655 - val_output_d6_accuracy: 0.9324 - val_output_d7_accuracy: 0.9399 - val_output_d8_accuracy: 0.9438 - val_output_d9_accuracy: 0.9436 - learning_rate: 1.0000e-04
# Training completed. Model saved to disk.

# %%
# CELL 11
# WORKING CODE

# Print the available keys in history.history
print("Available keys in history.history:")
print(history.history.keys())

# Plot loss and accuracy for each output
outputs = ['final_output', 'output_d6', 'output_d7', 'output_d8', 'output_d9']
plt.figure(figsize=(20, 10))

for i, output_name in enumerate(outputs):
    plt.subplot(2, 5, i+1)
    train_loss_key = f'{output_name}_loss'
    val_loss_key = f'val_{output_name}_loss'
    if train_loss_key in history.history:
        plt.plot(history.history[train_loss_key], label=f'{output_name} Training Loss')
    else:
        print(f"{train_loss_key} not found in history.history")
    if val_loss_key in history.history:
        plt.plot(history.history[val_loss_key], label=f'{output_name} Validation Loss')
    else:
        print(f"{val_loss_key} not found in history.history")
    plt.legend()
    plt.title(f'{output_name} Loss over Epochs')
    
    plt.subplot(2, 5, i+6)
    train_acc_key = f'{output_name}_accuracy'
    val_acc_key = f'val_{output_name}_accuracy'
    if train_acc_key in history.history:
        plt.plot(history.history[train_acc_key], label=f'{output_name} Training Accuracy')
    else:
        print(f"{train_acc_key} not found in history.history")
    if val_acc_key in history.history:
        plt.plot(history.history[val_acc_key], label=f'{output_name} Validation Accuracy')
    else:
        print(f"{val_acc_key} not found in history.history")
    plt.legend()
    plt.title(f'{output_name} Accuracy over Epochs')

plt.tight_layout()
plt.show()


# THIS IS CHANGEABLE
# EXPERIMENTAL CODE
# CELL 11
# Out:
# Available keys in history.history:
# dict_keys(['final_output_accuracy', 'final_output_iou_metric', 'loss', 'output_d6_accuracy', 'output_d7_accuracy', 'output_d8_accuracy', 'output_d9_accuracy', 'val_final_output_accuracy', 'val_final_output_iou_metric', 'val_loss', 'val_output_d6_accuracy', 'val_output_d7_accuracy', 'val_output_d8_accuracy', 'val_output_d9_accuracy', 'learning_rate'])
# final_output_loss not found in history.history
# val_final_output_loss not found in history.history
# output_d6_loss not found in history.history
# val_output_d6_loss not found in history.history
# output_d7_loss not found in history.history
# val_output_d7_loss not found in history.history
# output_d8_loss not found in history.history
# val_output_d8_loss not found in history.history
# output_d9_loss not found in history.history
# val_output_d9_loss not found in history.history

# %%
# # CELL 12: Compute IoU on Validation Set
# # WORKING CODE 
# from sklearn.metrics import accuracy_score, jaccard_score

# # Predict on validation data
# val_predictions = model.predict(X_val)

# # Extract the final output prediction
# val_predictions_final = val_predictions[0]  # Assuming final_output is the first output

# # Convert predictions to class labels
# val_predictions_labels = np.argmax(val_predictions_final, axis=-1)
# Y_val_labels = np.argmax(Y_val, axis=-1)

# # Flatten the arrays
# val_predictions_flat = val_predictions_labels.flatten()
# Y_val_flat = Y_val_labels.flatten()

# # Compute metrics
# accuracy = accuracy_score(Y_val_flat, val_predictions_flat)
# iou_score = jaccard_score(Y_val_flat, val_predictions_flat, average='macro')

# print("Validation Accuracy:", accuracy)
# print("Validation IoU Score:", iou_score)


# # EXPERIMENTAL CODE

# %%
# CELL 13: Compute IoU on Validation Set
# WORKING CODE 
from sklearn.metrics import accuracy_score, jaccard_score

# Predict on validation data
val_predictions = model.predict(X_val)

# Extract the final output prediction
val_predictions_final = val_predictions[0]  # Assuming final_output is the first output

# Convert predictions to class labels
val_predictions_labels = np.argmax(val_predictions_final, axis=-1)
Y_val_labels = np.argmax(Y_val, axis=-1)

# Flatten the arrays
val_predictions_flat = val_predictions_labels.flatten()
Y_val_flat = Y_val_labels.flatten()

# Compute metrics
accuracy = accuracy_score(Y_val_flat, val_predictions_flat)
iou_score = jaccard_score(Y_val_flat, val_predictions_flat, average='macro')

print("Validation Accuracy:", accuracy)
print("Validation IoU Score:", iou_score)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step
# Validation Accuracy: 0.9424453071925951
# Validation IoU Score: 0.6078276813914788

# %%
# CELL 14
# WORKING CODE

from sklearn.metrics import accuracy_score, jaccard_score, classification_report, confusion_matrix

# Ensure that model is trained and predictions are generated for the test set
test_predictions = model.predict(X_test)

# Assuming final_output is the first output, extract the prediction for final output
test_predictions_final = test_predictions[0]  # Adjust if necessary for your model's outputs

# Convert predictions to class labels
test_predictions_labels = np.argmax(test_predictions_final, axis=-1)
Y_test_labels = np.argmax(Y_test, axis=-1)

# Flatten the arrays
test_predictions_flat = test_predictions_labels.flatten()
Y_test_flat = Y_test_labels.flatten()

# Compute metrics
accuracy = accuracy_score(Y_test_flat, test_predictions_flat)
iou_score = jaccard_score(Y_test_flat, test_predictions_flat, average='macro')
print("Test Accuracy:", accuracy)
print("Test IoU Score:", iou_score)

# Compute IoU for each class
class_iou_scores = jaccard_score(Y_test_flat, test_predictions_flat, average=None)
class_labels = np.unique(Y_test_flat)
for class_id, iou in zip(class_labels, class_iou_scores):
    print(f"IoU for class {class_id}: {iou}")

# Classification Report
report = classification_report(Y_test_flat, test_predictions_flat, labels=class_labels)
print("\nClassification Report:\n", report)

# Confusion Matrix (optional, but useful for multi-class problems)
conf_matrix = confusion_matrix(Y_test_flat, test_predictions_flat)
print("\nConfusion Matrix:\n", conf_matrix)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 464ms/step
# Test Accuracy: 0.9405650496482849
# Test IoU Score: 0.6155889488453654
# IoU for class 0: 0.9349305820764546
# IoU for class 1: 0.6422330098835156
# IoU for class 2: 0.3901950139892262
# IoU for class 3: 0.49499718943226534
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97  14660915
#            1       0.72      0.86      0.78   2083485
#            2       0.51      0.63      0.56     14841
#            3       0.60      0.73      0.66     17975
#
#     accuracy                           0.94  16777216
#    macro avg       0.70      0.79      0.74  16777216
# weighted avg       0.95      0.94      0.94  16777216
#
#
# Confusion Matrix:
#  [[13973738   685486     1069      622]
#  [  285259  1783772     7449     7005]
#  [      60     4354     9344     1083]
#  [      50     4128      588    13209]]

# %%
# CELL 15
def convert_mask_to_rgb(mask):
    if len(mask.shape) > 2:
        mask = np.argmax(mask, axis=-1)
    rgb_mask = np.zeros((*mask.shape, 3), dtype=np.uint8)
    rgb_mask[mask == 0] = [0, 0, 0]        # Background (Black)
    # rgb_mask[mask == 1] = [128, 128, 128]  # Bone (Gray)
    rgb_mask[mask == 2] = [0, 0, 255]      # Cancer Hotspot (Red in BGR)
    # rgb_mask[mask == 3] = [0, 255, 0]      # Non-hotspot (Green)
    return rgb_mask

# %%
# CELL 16
# Specify the exact filenames you want to load
target_files = ['20.jpg', '32.jpg', '61.jpg', '75.jpg', '111.jpg', '139.jpg', ]

# Initialize lists to hold images and masks
images = []
masks = []
loaded_filenames = []  # To keep track of loaded filenames

# Load only specified images and their corresponding masks
for file in target_files:
    # Load and resize image
    image_path = os.path.join(image_dir, file)
    image = cv2.imread(image_path)
    if image is None:
        print(f"Could not read image {file}, skipping.")
        continue
    # Resize image: cv2.resize expects (width, height)
    image = cv2.resize(image, (img_width, img_height))
    image = image / 255.0  # Normalize image

    # Construct mask filename
    base_filename = os.path.splitext(file)[0]
    mask_filename = base_filename + '_colored_mask.npy'
    mask_path = os.path.join(mask_dir, mask_filename)
    if not os.path.exists(mask_path):
        print(f"Mask not found for image {file}, skipping.")
        continue

    # Load and resize mask
    mask = np.load(mask_path)
    mask = cv2.resize(mask, (img_width, img_height), interpolation=cv2.INTER_NEAREST)

    # Convert mask to one-hot encoding
    mask_one_hot = np.zeros((img_height, img_width, num_classes), dtype=np.uint8)
    for i in range(num_classes):
        mask_one_hot[..., i] = (mask == i).astype(np.uint8)

    images.append(image)
    masks.append(mask_one_hot)
    loaded_filenames.append(file)  # Keep track of the filename

# Convert lists to NumPy arrays
images = np.array(images)
masks = np.array(masks)

# Print the shapes
print("Images shape:", images.shape)
print("Masks shape:", masks.shape)
print("Loaded filenames:", loaded_filenames)  # List of loaded filenames to confirm
# Out:
# Images shape: (6, 512, 128, 3)
# Masks shape: (6, 512, 128, 4)
# Loaded filenames: ['20.jpg', '32.jpg', '61.jpg', '75.jpg', '111.jpg', '139.jpg']

# %%
# CELL 17
# WORKING CODE


# List of filenames to test
filenames = ["20.jpg", "32.jpg", "61.jpg", "75.jpg", "111.jpg", "139.jpg", "143.jpg", "158.jpg", "177.jpg", "182.jpg", "283.jpg", "301.jpg", "318.jpg"]

def overlay_mask(image, mask_rgb, alpha=0.5):
    if image.dtype != np.uint8:
        image = (image * 255).astype(np.uint8)
    if mask_rgb.dtype != np.uint8:
        mask_rgb = mask_rgb.astype(np.uint8)
    
    # Ensure both have 3 channels
    if len(image.shape) == 2:
        image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
    if len(mask_rgb.shape) == 2:
        mask_rgb = cv2.cvtColor(mask_rgb, cv2.COLOR_GRAY2BGR)

    # Ensure the shapes match
    if image.shape != mask_rgb.shape:
        height, width = image.shape[:2]
        mask_rgb = cv2.resize(mask_rgb, (width, height), interpolation=cv2.INTER_NEAREST)
    
    overlay = cv2.addWeighted(mask_rgb, alpha, image, 1 - alpha, 0)
    return overlay

def convert_mask_to_rgb(mask):
    if len(mask.shape) > 2:
        mask = np.argmax(mask, axis=-1)
    rgb_mask = np.zeros((mask.shape[0], mask.shape[1], 3), dtype=np.uint8)
    rgb_mask[mask == 0] = [0, 0, 0]        # Background (Black)
    # rgb_mask[mask == 1] = [128, 128, 128]  # Bone (Gray)
    rgb_mask[mask == 2] = [0, 0, 255]      # Cancer Hotspot (Red in BGR)
    rgb_mask[mask == 3] = [0, 255, 0]      # Non-hotspot (Green)
    return rgb_mask

def display_image(image, title):
    """
    Converts an image from BGR to RGB and displays it using Matplotlib.
    
    Parameters:
    - image: The image to display (in BGR format).
    - title: The title of the plot.
    """
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image_rgb)
    plt.title(title)
    plt.axis('off')

# Load the best weights
weights_file = os.path.join(checkpoint_dir, "unetplusplus_best.weights.h5")
if os.path.exists(weights_file):
    print("Loading best weights from:", weights_file)
    model.load_weights(weights_file)
else:
    print("No weights files found. Please check your checkpoint directory.")

# Predict and display results
for filename in filenames:
    # Load image in color mode
    image_path = os.path.join(image_dir, filename)
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    if image is None:
        print(f"Image {filename} not found, skipping.")
        continue

    # Resize and normalize image
    image_resized = cv2.resize(image, (img_width, img_height))
    image_normalized = image_resized / 255.0  # Normalize for prediction
    
    # Load ground truth mask
    mask_filename = filename.split('.')[0] + '_colored_mask.npy'
    mask_path = os.path.join(mask_dir, mask_filename)
    if not os.path.exists(mask_path):
        print(f"Mask for {filename} not found, skipping.")
        continue
    mask = np.load(mask_path)
    mask = cv2.resize(mask, (img_width, img_height), interpolation=cv2.INTER_NEAREST)
    
    # Convert ground truth mask to RGB and create overlay
    mask_rgb_gt = convert_mask_to_rgb(mask)
    overlay_gt = overlay_mask(image_resized, mask_rgb_gt, alpha=0.5)
    if overlay_gt is None:
        print(f"Error creating overlay for ground truth of {filename}, skipping.")
        continue

    # Perform prediction
    predictions = model.predict(image_normalized[np.newaxis, ...])  # Add batch dimension
    
    # Extract the final output prediction
    pred_mask_probs = predictions[0][0]  # Get the first prediction and remove batch dimension
    pred_mask = np.argmax(pred_mask_probs, axis=-1)
    print(f"Unique labels in predicted mask for {filename}:", np.unique(pred_mask))
    
    # Convert predicted mask to RGB and create overlay
    mask_rgb_pred = convert_mask_to_rgb(pred_mask)
    overlay_pred = overlay_mask(image_resized, mask_rgb_pred, alpha=0.5)
    if overlay_pred is None:
        print(f"Error creating overlay for prediction of {filename}, skipping.")
        continue

    # Plot the results
    plt.figure(figsize=(20, 5))

    plt.subplot(1, 4, 1)
    display_image(image_resized, f'Original Image {filename}')

    plt.subplot(1, 4, 2)
    display_image(overlay_gt, f'Overlay with Ground Truth {filename}')

    plt.subplot(1, 4, 3)
    display_image(overlay_pred, f'Overlay with Predicted Mask {filename}')

    plt.subplot(1, 4, 4)
    display_image(mask_rgb_pred, f'Predicted Mask {filename}')

    plt.show()
# Out:
# Loading best weights from: /kaggle/working/unetplusplus_best.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Unique labels in predicted mask for 20.jpg: [0 1 2 3]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Unique labels in predicted mask for 32.jpg: [0 1 2 3]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Unique labels in predicted mask for 61.jpg: [0 1 2]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Unique labels in predicted mask for 75.jpg: [0 1 2 3]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Unique labels in predicted mask for 111.jpg: [0 1 2 3]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Unique labels in predicted mask for 139.jpg: [0 1 2 3]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Unique labels in predicted mask for 143.jpg: [0 1 2]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Unique labels in predicted mask for 158.jpg: [0 1 2 3]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Unique labels in predicted mask for 177.jpg: [0 1 2 3]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Unique labels in predicted mask for 182.jpg: [0 1 2 3]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Unique labels in predicted mask for 283.jpg: [0 1 2 3]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Unique labels in predicted mask for 301.jpg: [0 1 2 3]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Unique labels in predicted mask for 318.jpg: [0 1 2 3]

# %%
from tensorflow.keras.models import load_model

# Pastikan Anda mendefinisikan kembali fungsi loss dan metric kustom
import tensorflow.keras.backend as K
import tensorflow as tf
import numpy as np

# Definisikan kembali atau muat ulang class_weights
# Jika Anda menggunakan class_weights yang sama seperti saat training
class_weights = np.array([0.5, 1.0, 5.0, 5.0])  # Sesuaikan sesuai dengan yang digunakan saat training

def focal_loss(gamma=2., alpha=class_weights):
    alpha = K.constant(alpha, dtype=tf.float32)
    gamma = float(gamma)

    def focal_loss_fixed(y_true, y_pred):
        y_pred = K.clip(y_pred, K.epsilon(), 1. - K.epsilon())
        cross_entropy = -y_true * K.log(y_pred)
        weight = alpha * K.pow(1 - y_pred, gamma)
        loss = weight * cross_entropy
        return K.sum(loss, axis=-1)

    return focal_loss_fixed

def dice_loss(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    smooth = 1e-6
    return 1 - (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def combined_loss(y_true, y_pred):
    return focal_loss()(y_true, y_pred) + dice_loss(y_true, y_pred)

# Implementasi metric IoU
def iou_metric(y_true, y_pred):
    y_pred = K.argmax(y_pred, axis=-1)
    y_true = K.argmax(y_true, axis=-1)
    intersection = K.sum(K.cast(y_true * y_pred, 'float32') * K.cast(y_pred, 'float32'))
    union = K.sum(K.cast(y_true, 'float32') + K.cast(y_pred, 'float32')) - intersection
    return intersection / (union + K.epsilon())

# Definisikan custom objects untuk memuat model
custom_objects = {
    'combined_loss': combined_loss,
    'iou_metric': iou_metric
}

# Path model yang disimpan
model_path = '/kaggle/working/unetplusplus_final.h5'

# Memuat model
model = load_model(model_path, custom_objects=custom_objects)

print(f"Model berhasil dimuat dari {model_path}")
# Out:
# Model berhasil dimuat dari /kaggle/working/unetplusplus_final.h5

# %%
# CELL 19

# Assuming you have already loaded the model in CELL 18
# and you have X_test and Y_test from CELL 4

# Predict on test data
test_predictions = model.predict(X_test)

# Extract the final output prediction
test_predictions_final = test_predictions[0]  # Assuming 'final_output' is the first output

# Convert predictions to class labels
test_predictions_labels = np.argmax(test_predictions_final, axis=-1)
Y_test_labels = np.argmax(Y_test, axis=-1)

# Flatten the arrays for metric computation
test_predictions_flat = test_predictions_labels.flatten()
Y_test_flat = Y_test_labels.flatten()

# Compute metrics
from sklearn.metrics import accuracy_score, jaccard_score, classification_report

class_labels = [0, 1, 2, 3]

# Compute Accuracy
accuracy = accuracy_score(Y_test_flat, test_predictions_flat)
print("Test Accuracy:", accuracy)

# Compute Mean IoU
iou_score = jaccard_score(Y_test_flat, test_predictions_flat, average='macro', labels=class_labels)
print("Mean IoU Score:", iou_score)

# Compute IoU for each class
class_iou_scores = jaccard_score(Y_test_flat, test_predictions_flat, average=None, labels=class_labels)
for class_id, iou in zip(class_labels, class_iou_scores):
    print(f"IoU for class {class_id}: {iou}")

# Classification Report
report = classification_report(Y_test_flat, test_predictions_flat, labels=class_labels)
print("\nClassification Report:\n", report)

# Optionally, display some test images with their predicted masks
import random
import matplotlib.pyplot as plt

num_samples = 5  # Number of test samples to display
indices = random.sample(range(len(X_test)), num_samples)

for idx in indices:
    image = X_test[idx]
    true_mask = Y_test_labels[idx]
    pred_mask = test_predictions_labels[idx]
    
    # Convert masks to RGB
    true_mask_rgb = convert_mask_to_rgb(true_mask)
    pred_mask_rgb = convert_mask_to_rgb(pred_mask)
    
    # Original image (rescale for display)
    image_disp = (image * 255).astype(np.uint8)
    
    # Overlays
    overlay_true = overlay_mask(image_disp, true_mask_rgb, alpha=0.5)
    overlay_pred = overlay_mask(image_disp, pred_mask_rgb, alpha=0.5)
    
    # Plot the results
    plt.figure(figsize=(15, 5))
    
    plt.subplot(1, 4, 1)
    display_image(image_disp, 'Original Image')
    
    plt.subplot(1, 4, 2)
    display_image(overlay_true, 'Overlay with Ground Truth Mask')
    
    plt.subplot(1, 4, 3)
    display_image(overlay_pred, 'Overlay with Predicted Mask')
    
    plt.subplot(1, 4, 4)
    display_image(pred_mask_rgb, 'Predicted Mask')
    
    plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 458ms/step
# Test Accuracy: 0.9405650496482849
# Mean IoU Score: 0.6155889488453654
# IoU for class 0: 0.9349305820764546
# IoU for class 1: 0.6422330098835156
# IoU for class 2: 0.3901950139892262
# IoU for class 3: 0.49499718943226534
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97  14660915
#            1       0.72      0.86      0.78   2083485
#            2       0.51      0.63      0.56     14841
#            3       0.60      0.73      0.66     17975
#
#     accuracy                           0.94  16777216
#    macro avg       0.70      0.79      0.74  16777216
# weighted avg       0.95      0.94      0.94  16777216
